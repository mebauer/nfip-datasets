# %% [markdown]
# # How to Download NFIP Datasets from OpenFEMA
# Author: Mark Bauer

# %%
# import libraries
import logging
from datetime import datetime
from urllib.parse import urlencode
import requests
import duckdb
import pandas as pd

# %%
# reproducibility
# %reload_ext watermark
# %watermark -v -p requests,duckdb,pandas
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# requests: 2.28.1
# duckdb  : 1.0.0
# pandas  : 1.5.1

# %%
# data retrieved, not to be confused with data of data
current_date = datetime.now()
print(f"The data was retrieved on {current_date.strftime('%Y-%m-%d')}.")
# Out:
# The data was retrieved on 2025-05-31.

# %% [markdown]
# # Overview
# This notebook demonstrates how to download and work with the National Flood Insurance Program (NFIP) [datasets](https://www.fema.gov/about/openfema/data-sets#nfip) from [OpenFEMA](https://www.fema.gov/about/reports-and-data/openfema). The workflows are designed to be efficient, easy to adapt, and easy to understand. These examples also include brief data exploration using [DuckDB](https://duckdb.org/).
#
# ## Datasets
# - [FIMA NFIP Redacted Claims - v2](https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2)
# - [FIMA NFIP Redacted Policies - v2](https://www.fema.gov/openfema-data-page/fima-nfip-redacted-policies-v2)
# - [NFIP Multiple Loss Properties - v1](https://www.fema.gov/openfema-data-page/nfip-multiple-loss-properties-v1)
# - [NFIP Residential Penetration Rates - v1](https://www.fema.gov/openfema-data-page/nfip-residential-penetration-rates-v1)
# - [2023 NFIP Reinsurance Placement Information](https://www.fema.gov/about/openfema/data-sets/national-flood-insurance-program-nfip-reinsurance-placement-information)
# - [NFIP Community Layer Comprehensive - v1](https://www.fema.gov/openfema-data-page/nfip-community-layer-comprehensive-v1)
# - [NFIP Community Layer No Overlaps Split - v1](https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-split-v1)
# - [NFIP Community Layer No Overlaps Whole - v1](https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-whole-v1)
# - [NFIP Community Status Book - v1](https://www.fema.gov/openfema-data-page/nfip-community-status-book-v1)
#
# ## Notes
# - Datasets are downloaded in Parquet format whenever possible for performance and compatibility.
# - DuckDB is used for querying and previewing the data.
# - The NFIP Community Layers dataset is large and has been excluded from this repository (tracked via .gitignore), but other datasets are included both locally and on GitHub.
# - For the NFIP Policies and Claims datasets, the current focus is on a sample of New York City.
#
# ## Disclaimer
# This analysis uses the Federal Emergency Management Agency’s OpenFEMA API, but is not endorsed by FEMA. The Federal Government or FEMA cannot vouch for the data or analyses derived from these data after the data have been retrieved from the Agency's website(s).
#
# Read more about OpenFEMA's [Terms and Conditions](https://www.fema.gov/about/openfema/terms-conditions).

# %% [markdown]
# # Dataset Metadata
# Before we get started, let's review the metadata for each dataset. Luckily, the OpenFEMA API has a great endpoint for this, `OpenFemaDataSets`.

# %%
url = (
    "https://www.fema.gov/api/open/v1/OpenFemaDataSets"
    "?$filter=theme eq 'National Flood Insurance Program'"
)

response = requests.get(url)

if response.ok:
    data = response.json()
    metadata_df = pd.DataFrame(data['OpenFemaDataSets'])
else:
    print(f"Failed to download data. Status code: {response.status_code}")
    
# preview data    
print(metadata_df.shape)    
metadata_df
# Out:
# (8, 39)
#     identifier                               name  \
# 0  openfema-86    NfipResidentialPenetrationRates
# 1  openfema-78         NfipMultipleLossProperties
# 2  openfema-39            NfipCommunityStatusBook
# 3  openfema-74                   FimaNfipPolicies
# 4  openfema-77    NfipCommunityLayerComprehensive
# 5  openfema-73                     FimaNfipClaims
# 6  openfema-76  NfipCommunityLayerNoOverlapsSplit
# 7  openfema-75  NfipCommunityLayerNoOverlapsWhole
#
#                                     title  \
# 0      NFIP Residential Penetration Rates
# 1           NFIP Multiple Loss Properties
# 2              NFIP Community Status Book
# 3             FIMA NFIP Redacted Policies
# 4      NFIP Community Layer Comprehensive
# 5               FIMA NFIP Redacted Claims
# 6  NFIP Community Layer No Overlaps Split
# 7  NFIP Community Layer No Overlaps Whole
#
#                                          description  \
# 0  NFIP "take-up rates" or residential penetratio...
# 1  This dataset provides information on structure...
# 2  The National Flood Insurance Program (NFIP) en...
# 3  Congress passed the National Flood Insurance A...
# 4  This dataset is also known as the 3d layer and...
# 5  Congress passed the National Flood Insurance A...
# 6  This dataset is flattened and multicounty comm...
# 7  This dataset is flattened and multicounty comm...
#
#                                           webService  \
# 0  https://www.fema.gov/api/open/v1/NfipResidenti...
# 1  https://www.fema.gov/api/open/v1/NfipMultipleL...
# 2  https://www.fema.gov/api/open/v1/NfipCommunity...
# 3  https://www.fema.gov/api/open/v2/FimaNfipPolicies
# 4  https://www.fema.gov/api/open/v1/NfipCommunity...
# 5    https://www.fema.gov/api/open/v2/FimaNfipClaims
# 6  https://www.fema.gov/api/open/v1/NfipCommunity...
# 7  https://www.fema.gov/api/open/v1/NfipCommunity...
#
#                                       dataDictionary  \
# 0  https://www.fema.gov/openfema-data-page/nfip-r...
# 1  https://www.fema.gov/openfema-data-page/NFIP-M...
# 2  https://www.fema.gov/openfema-data-page/nfip-c...
# 3  https://www.fema.gov/openfema-data-page/fima-n...
# 4  https://www.fema.gov/openfema-data-page/nfip-c...
# 5  https://www.fema.gov/openfema-data-page/fima-n...
# 6  https://www.fema.gov/openfema-data-page/nfip-c...
# 7  https://www.fema.gov/openfema-data-page/nfip-c...
#
#                                              keyword  \
# 0  [nfip, rates, nsi, residential structures, pol...
# 1  [NFIP, Insurance, Flood, Repetitive Loss, Dama...
# 2  [NFIP, Status Book, Community Status Book, Flo...
# 3            [NFIP, Flood, Insurance, Policy, Water]
# 4   [nfip community, geospatial, census, boundaries]
# 5              [NFIP, FIMA, claims, flood insurance]
# 6   [nfip community, geospatial, census, boundaries]
# 7   [nfip community, geospatial, census, boundaries]
#
#                    modified                            publisher contactPoint  \
# 0  2024-11-07T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 1  2024-02-27T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 2  2024-11-07T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 3  2025-04-01T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 4  2024-02-22T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 5  2023-03-24T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 6  2024-02-22T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 7  2024-02-22T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
#
#    ... recordCount depDate depApiMessage depWebMessage  depNewURL  \
# 0  ...        3162    None          None          None       None
# 1  ...      257374    None          None          None       None
# 2  ...       25053    None          None          None       None
# 3  ...    69829956    None          None          None       None
# 4  ...       51943    None          None          None       None
# 5  ...     2712269    None          None          None       None
# 6  ...       37918    None          None          None       None
# 7  ...       29898    None          None          None       None
#
#                                        hash               lastRefresh  \
# 0  c84151b7bbe46b75c5143a0c9d491a9986247f06  2024-11-21T14:40:15.168Z
# 1  c6474d2bed656468b54afcb63f3da841959535a5  2024-11-21T14:40:15.168Z
# 2  7b8f6d05763d0c656c524c44438e1d8e8552abe8  2024-11-21T14:40:15.168Z
# 3  85c6b91e237853b3333b06b4e3ebf5cdef930060  2025-04-01T20:00:37.246Z
# 4  51551de69709270cbb3dc05a9da88e92be099c2d  2024-12-05T22:20:23.322Z
# 5  843979427d2c4cc20e139ce661e6b0476975431f  2024-11-21T14:40:15.168Z
# 6  8db6fcd098f2b2bf16a3dc6b10ccb93543d32010  2024-12-05T22:20:23.322Z
# 7  7bdabebd0a0805adbb76fee3ca61bbd4a5f5c0b7  2024-12-05T22:20:23.322Z
#
#                                      id        lastDataSetRefresh  \
# 0  18f6002e-40a5-4601-9504-279b8e6bf985  2025-05-19T15:20:16.607Z
# 1  f3cfd1cd-ea0d-455c-bfcd-f99625ecd393  2024-12-17T20:40:57.000Z
# 2  edccafe8-40f9-472a-84a9-e7cbbab850e2  2025-05-31T18:54:09.445Z
# 3  3776bead-efe2-4590-84eb-3e000f869701  2025-05-14T13:43:49.278Z
# 4  0131d365-5a18-47a0-98cb-558149c165ee  2024-12-05T18:09:51.898Z
# 5  e9343760-d76e-44db-b947-822642353e7f  2025-05-14T13:01:34.036Z
# 6  57d33198-ea17-4255-83fe-35742b8f601b  2024-12-05T18:09:57.312Z
# 7  e2c2268c-7a3c-4ce1-830e-ac5f735ee44c  2024-12-05T18:10:50.474Z
#
#                                         distribution
# 0  [{'format': 'csv', 'accessURL': 'https://www.f...
# 1  [{'format': 'csv', 'accessURL': 'https://www.f...
# 2  [{'format': 'csv', 'accessURL': 'https://www.f...
# 3  [{'format': 'csv', 'accessURL': 'https://www.f...
# 4  [{'format': 'csv', 'accessURL': 'https://www.f...
# 5  [{'format': 'csv', 'accessURL': 'https://www.f...
# 6  [{'format': 'csv', 'accessURL': 'https://www.f...
# 7  [{'format': 'csv', 'accessURL': 'https://www.f...
#
# [8 rows x 39 columns]

# %%
# first 15 columns
metadata_df.iloc[:, :15]
# Out:
#     identifier                               name  \
# 0  openfema-86    NfipResidentialPenetrationRates
# 1  openfema-78         NfipMultipleLossProperties
# 2  openfema-39            NfipCommunityStatusBook
# 3  openfema-74                   FimaNfipPolicies
# 4  openfema-77    NfipCommunityLayerComprehensive
# 5  openfema-73                     FimaNfipClaims
# 6  openfema-76  NfipCommunityLayerNoOverlapsSplit
# 7  openfema-75  NfipCommunityLayerNoOverlapsWhole
#
#                                     title  \
# 0      NFIP Residential Penetration Rates
# 1           NFIP Multiple Loss Properties
# 2              NFIP Community Status Book
# 3             FIMA NFIP Redacted Policies
# 4      NFIP Community Layer Comprehensive
# 5               FIMA NFIP Redacted Claims
# 6  NFIP Community Layer No Overlaps Split
# 7  NFIP Community Layer No Overlaps Whole
#
#                                          description  \
# 0  NFIP "take-up rates" or residential penetratio...
# 1  This dataset provides information on structure...
# 2  The National Flood Insurance Program (NFIP) en...
# 3  Congress passed the National Flood Insurance A...
# 4  This dataset is also known as the 3d layer and...
# 5  Congress passed the National Flood Insurance A...
# 6  This dataset is flattened and multicounty comm...
# 7  This dataset is flattened and multicounty comm...
#
#                                           webService  \
# 0  https://www.fema.gov/api/open/v1/NfipResidenti...
# 1  https://www.fema.gov/api/open/v1/NfipMultipleL...
# 2  https://www.fema.gov/api/open/v1/NfipCommunity...
# 3  https://www.fema.gov/api/open/v2/FimaNfipPolicies
# 4  https://www.fema.gov/api/open/v1/NfipCommunity...
# 5    https://www.fema.gov/api/open/v2/FimaNfipClaims
# 6  https://www.fema.gov/api/open/v1/NfipCommunity...
# 7  https://www.fema.gov/api/open/v1/NfipCommunity...
#
#                                       dataDictionary  \
# 0  https://www.fema.gov/openfema-data-page/nfip-r...
# 1  https://www.fema.gov/openfema-data-page/NFIP-M...
# 2  https://www.fema.gov/openfema-data-page/nfip-c...
# 3  https://www.fema.gov/openfema-data-page/fima-n...
# 4  https://www.fema.gov/openfema-data-page/nfip-c...
# 5  https://www.fema.gov/openfema-data-page/fima-n...
# 6  https://www.fema.gov/openfema-data-page/nfip-c...
# 7  https://www.fema.gov/openfema-data-page/nfip-c...
#
#                                              keyword  \
# 0  [nfip, rates, nsi, residential structures, pol...
# 1  [NFIP, Insurance, Flood, Repetitive Loss, Dama...
# 2  [NFIP, Status Book, Community Status Book, Flo...
# 3            [NFIP, Flood, Insurance, Policy, Water]
# 4   [nfip community, geospatial, census, boundaries]
# 5              [NFIP, FIMA, claims, flood insurance]
# 6   [nfip community, geospatial, census, boundaries]
# 7   [nfip community, geospatial, census, boundaries]
#
#                    modified                            publisher contactPoint  \
# 0  2024-11-07T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 1  2024-02-27T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 2  2024-11-07T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 3  2025-04-01T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 4  2024-02-22T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 5  2023-03-24T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 6  2024-02-22T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
# 7  2024-02-22T00:00:00.000Z  Federal Emergency Management Agency     OpenFEMA
#
#                 mbox accessLevel                                 landingPage  \
# 0  openfema@fema.gov      public        https://www.fema.gov/flood-insurance
# 1  openfema@fema.gov      public        https://www.fema.gov/flood-insurance
# 2  openfema@fema.gov      public  https://www.fema.gov/floodplain-management
# 3  openfema@fema.gov      public        https://www.fema.gov/flood-insurance
# 4  openfema@fema.gov      public        https://www.fema.gov/flood-insurance
# 5  openfema@fema.gov      public        https://www.fema.gov/flood-insurance
# 6  openfema@fema.gov      public        https://www.fema.gov/flood-insurance
# 7  openfema@fema.gov      public        https://www.fema.gov/flood-insurance
#
#       temporal   api
# 0         None  True
# 1  1978-01-01/  True
# 2  1968-01-01/  True
# 3  2009-01-01/  True
# 4         None  True
# 5  1970-08-31/  True
# 6         None  True
# 7         None  True

# %%
# next 15 columns
metadata_df.iloc[:, 15:30]
# Out:
#    version bureauCode programCode accessLevelComment license spatial  \
# 0        1   [024:70]   [024:039]               None    None    None
# 1        1   [024:70]   [024:039]               None    None    None
# 2        1   [024:70]   [024:039]               None    None    None
# 3        2   [024:70]   [024:039]               None    None    None
# 4        1   [024:70]   [024:039]               None    None    None
# 5        2   [024:70]   [024:039]               None    None    None
# 6        1   [024:70]   [024:039]               None    None    None
# 7        1   [024:70]   [024:039]               None    None    None
#
#                               theme dataQuality accrualPeriodicity language  \
# 0  National Flood Insurance Program        true              R/P3M    en-US
# 1  National Flood Insurance Program        true              R/P1Y    en-US
# 2  National Flood Insurance Program        true              R/P1D    en-US
# 3  National Flood Insurance Program        true              R/P1M    en-US
# 4  National Flood Insurance Program        true              R/P1Y    en-US
# 5  National Flood Insurance Program        true              R/P1M    en-US
# 6  National Flood Insurance Program        true              R/P1Y    en-US
# 7  National Flood Insurance Program        true              R/P1Y    en-US
#
#   primaryITInvestmentUII                                         references  \
# 0                   None                                                 []
# 1                   None  [https://agents.floodsmart.gov/sites/default/f...
# 2                   None                                                 []
# 3                   None  [https://nfipservices.floodsmart.gov/manuals/j...
# 4                   None                                                 []
# 5                   None  [https://nfipservices.floodsmart.gov/manuals/j...
# 6                   None                                                 []
# 7                   None                                                 []
#
#                      issued systemOfRecords  recordCount
# 0  2024-11-08T00:00:00.000Z            None         3162
# 1  2024-02-12T00:00:00.000Z            None       257374
# 2  1968-01-01T00:00:00.000Z            None        25053
# 3  2019-06-01T00:00:00.000Z            None     69829956
# 4  2024-02-09T00:00:00.000Z            None        51943
# 5  2019-06-01T00:00:00.000Z            None      2712269
# 6  2024-02-09T00:00:00.000Z            None        37918
# 7  2024-02-09T00:00:00.000Z            None        29898

# %%
# columns to the end
metadata_df.iloc[:, 30:]
# Out:
#   depDate depApiMessage depWebMessage depNewURL  \
# 0    None          None          None      None
# 1    None          None          None      None
# 2    None          None          None      None
# 3    None          None          None      None
# 4    None          None          None      None
# 5    None          None          None      None
# 6    None          None          None      None
# 7    None          None          None      None
#
#                                        hash               lastRefresh  \
# 0  c84151b7bbe46b75c5143a0c9d491a9986247f06  2024-11-21T14:40:15.168Z
# 1  c6474d2bed656468b54afcb63f3da841959535a5  2024-11-21T14:40:15.168Z
# 2  7b8f6d05763d0c656c524c44438e1d8e8552abe8  2024-11-21T14:40:15.168Z
# 3  85c6b91e237853b3333b06b4e3ebf5cdef930060  2025-04-01T20:00:37.246Z
# 4  51551de69709270cbb3dc05a9da88e92be099c2d  2024-12-05T22:20:23.322Z
# 5  843979427d2c4cc20e139ce661e6b0476975431f  2024-11-21T14:40:15.168Z
# 6  8db6fcd098f2b2bf16a3dc6b10ccb93543d32010  2024-12-05T22:20:23.322Z
# 7  7bdabebd0a0805adbb76fee3ca61bbd4a5f5c0b7  2024-12-05T22:20:23.322Z
#
#                                      id        lastDataSetRefresh  \
# 0  18f6002e-40a5-4601-9504-279b8e6bf985  2025-05-19T15:20:16.607Z
# 1  f3cfd1cd-ea0d-455c-bfcd-f99625ecd393  2024-12-17T20:40:57.000Z
# 2  edccafe8-40f9-472a-84a9-e7cbbab850e2  2025-05-31T18:54:09.445Z
# 3  3776bead-efe2-4590-84eb-3e000f869701  2025-05-14T13:43:49.278Z
# 4  0131d365-5a18-47a0-98cb-558149c165ee  2024-12-05T18:09:51.898Z
# 5  e9343760-d76e-44db-b947-822642353e7f  2025-05-14T13:01:34.036Z
# 6  57d33198-ea17-4255-83fe-35742b8f601b  2024-12-05T18:09:57.312Z
# 7  e2c2268c-7a3c-4ce1-830e-ac5f735ee44c  2024-12-05T18:10:50.474Z
#
#                                         distribution
# 0  [{'format': 'csv', 'accessURL': 'https://www.f...
# 1  [{'format': 'csv', 'accessURL': 'https://www.f...
# 2  [{'format': 'csv', 'accessURL': 'https://www.f...
# 3  [{'format': 'csv', 'accessURL': 'https://www.f...
# 4  [{'format': 'csv', 'accessURL': 'https://www.f...
# 5  [{'format': 'csv', 'accessURL': 'https://www.f...
# 6  [{'format': 'csv', 'accessURL': 'https://www.f...
# 7  [{'format': 'csv', 'accessURL': 'https://www.f...

# %% [markdown]
# # Download Tutorial

# %% [markdown]
# Code to download the NFIP Policies and Claims datasets using the OpenFEMA API. In this tutorial, we only export data in New York City.

# %%
BASE_URL = "https://www.fema.gov/api/open/v2/FimaNfip{}?"
PAGE_SIZE = 10000

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def build_url(dataset, fips, skip):
    params = {
        "$format": "json",
        "$filter": f"countyCode eq '{fips}'",
        "$top": PAGE_SIZE,
        "$skip": skip,
        "$metadata": "off",
    }
    return BASE_URL.format(dataset.capitalize()), params

def fetch_single_fips(dataset, fips):
    records = []
    skip = 0
    logging.info(f"Starting download for FIPS {fips}")

    while True:
        url, params = build_url(dataset, fips, skip)
        try:
            logging.info(f"Requesting: skip={skip}")
            response = requests.get(url, params=params, timeout=10)
            response.raise_for_status()
            page = response.json().get(f"FimaNfip{dataset}", [])
            if not page:
                logging.info(f"No more data for FIPS {fips} at skip={skip}")
                break
            records.extend(page)
            if len(page) < PAGE_SIZE:
                logging.info(f"Final page for FIPS {fips} retrieved")
                break
            skip += PAGE_SIZE
        except requests.RequestException as e:
            logging.error(f"Error fetching data for FIPS {fips} at skip={skip}: {e}")
            break

    logging.info(f"Finished download for FIPS {fips}: {len(records)} records")
    return records

def fetch_nfip_data(dataset, fips_list, output_path):
    all_data = []
    for fips in fips_list:
        all_data.extend(fetch_single_fips(dataset, fips))

    if all_data:
        df = pd.DataFrame(all_data)
        df.to_parquet(output_path, index=False)
        logging.info(f"Saved {len(df)} records to {output_path}")
    else:
        logging.warning("No data fetched. Nothing to save.")

# %% [markdown]
# # OpenFEMA Dataset: FIMA NFIP Redacted Claims - v2
# https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2

# %%
# %%time

fips_list = [
    "36005",
    "36047",
    "36061",
    "36081",
    "36085"
]

output_path = "data/nyc-claims.parquet"

fetch_nfip_data("Claims", fips_list=fips_list, output_path=output_path)
# Out:
# 2025-05-31 15:29:11,405 - INFO - Starting download for FIPS 36005
# 2025-05-31 15:29:11,406 - INFO - Requesting: skip=0
# 2025-05-31 15:29:14,405 - INFO - Final page for FIPS 36005 retrieved
# 2025-05-31 15:29:14,406 - INFO - Finished download for FIPS 36005: 1943 records
# 2025-05-31 15:29:14,406 - INFO - Starting download for FIPS 36047
# 2025-05-31 15:29:14,407 - INFO - Requesting: skip=0
# 2025-05-31 15:29:18,497 - INFO - Final page for FIPS 36047 retrieved
# 2025-05-31 15:29:18,498 - INFO - Finished download for FIPS 36047: 6263 records
# 2025-05-31 15:29:18,500 - INFO - Starting download for FIPS 36061
# 2025-05-31 15:29:18,500 - INFO - Requesting: skip=0
# 2025-05-31 15:29:20,285 - INFO - Final page for FIPS 36061 retrieved
# 2025-05-31 15:29:20,286 - INFO - Finished download for FIPS 36061: 1486 records
# 2025-05-31 15:29:20,287 - INFO - Starting download for FIPS 36081
# 2025-05-31 15:29:20,287 - INFO - Requesting: skip=0
# 2025-05-31 15:29:24,656 - INFO - Requesting: skip=10000
# 2025-05-31 15:29:27,558 - INFO - Final page for FIPS 36081 retrieved
# 2025-05-31 15:29:27,559 - INFO - Finished download for FIPS 36081: 14873 records
# 2025-05-31 15:29:27,561 - INFO - Starting download for FIPS 36085
# 2025-05-31 15:29:27,562 - INFO - Requesting: skip=0
# 2025-05-31 15:29:32,273 - INFO - Requesting: skip=10000
# 2025-05-31 15:29:38,636 - INFO - Final page for FIPS 36085 retrieved
# 2025-05-31 15:29:38,636 - INFO - Finished download for FIPS 36085: 19414 records
# 2025-05-31 15:29:39,633 - INFO - Saved 43979 records to data/nyc-claims.parquet
# CPU times: user 2.27 s, sys: 302 ms, total: 2.58 s
# Wall time: 28.3 s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/nyc-claims.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      43979 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/nyc-claims.parquet')
    LIMIT 5
""").df()
# Out:
#    agricultureStructureIndicator asOfDate  basementEnclosureCrawlspaceType  \
# 0                          False     None                              1.0
# 1                          False     None                              NaN
# 2                          False     None                              NaN
# 3                          False     None                              NaN
# 4                          False     None                              NaN
#
#    policyCount  crsClassificationCode                dateOfLoss  \
# 0            1                    NaN  2021-09-01T00:00:00.000Z
# 1            1                    NaN  1984-03-08T00:00:00.000Z
# 2            1                    NaN  1979-01-24T00:00:00.000Z
# 3            1                    NaN  2012-10-29T00:00:00.000Z
# 4            1                    NaN  1992-12-11T00:00:00.000Z
#
#    elevatedBuildingIndicator elevationCertificateIndicator  \
# 0                      False                          None
# 1                      False                          None
# 2                      False                          None
# 3                      False                          None
# 4                      False                          None
#
#    elevationDifference  baseFloodElevation  ... rentalPropertyIndicator  \
# 0                  NaN                 NaN  ...                   False
# 1                  NaN                 NaN  ...                   False
# 2                  NaN                 NaN  ...                   False
# 3                  NaN                 NaN  ...                   False
# 4                  NaN                 NaN  ...                   False
#
#    state           reportedCity  reportedZipCode  countyCode  censusTract  \
# 0     NY  Currently Unavailable            10475       36005  36005045600
# 1     NY  Currently Unavailable            10465       36005  36005027402
# 2     NY  Currently Unavailable            10463       36005  36005030100
# 3     NY  Currently Unavailable            10465       36005  36005013200
# 4     NY  Currently Unavailable            10465       36005  36005013200
#
#    censusBlockGroupFips  latitude  longitude  \
# 0          360050456003      40.9      -73.8
# 1          360050274023      40.8      -73.8
# 2          360050301001      40.9      -73.9
# 3          360050132003      40.8      -73.8
# 4          360050132001      40.8      -73.8
#
#                                      id
# 0  99d7829c-e79c-4b8b-9de7-af1863973b42
# 1  f4a3f994-52e8-4823-9a2d-58d9ea0d2577
# 2  99044017-de9b-4a48-8473-7d229d5fea7a
# 3  e848b356-c15b-4481-b498-598868ffc8bd
# 4  fc26b2e2-4ae8-4f0c-a27d-c8560631c901
#
# [5 rows x 73 columns]

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/nyc-claims.parquet'))
""").show(max_rows=100)
# Out:
# ┌────────────────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │                column_name                 │ column_type │  null   │   key   │ default │  extra  │
# │                  varchar                   │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ agricultureStructureIndicator              │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ asOfDate                                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ basementEnclosureCrawlspaceType            │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ policyCount                                │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ crsClassificationCode                      │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ dateOfLoss                                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ elevatedBuildingIndicator                  │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ elevationCertificateIndicator              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ elevationDifference                        │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ baseFloodElevation                         │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ ratedFloodZone                             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ houseWorship                               │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ locationOfContents                         │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ lowestAdjacentGrade                        │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ lowestFloorElevation                       │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ numberOfFloorsInTheInsuredBuilding         │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ nonProfitIndicator                         │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ obstructionType                            │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ occupancyType                              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ originalConstructionDate                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ originalNBDate                             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ amountPaidOnBuildingClaim                  │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ amountPaidOnContentsClaim                  │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ amountPaidOnIncreasedCostOfComplianceClaim │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ postFIRMConstructionIndicator              │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ rateMethod                                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ smallBusinessIndicatorBuilding             │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ totalBuildingInsuranceCoverage             │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ totalContentsInsuranceCoverage             │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ yearOfLoss                                 │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ primaryResidenceIndicator                  │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingDamageAmount                       │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingDeductibleCode                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ netBuildingPaymentAmount                   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingPropertyValue                      │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ causeOfDamage                              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ condominiumCoverageTypeCode                │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ contentsDamageAmount                       │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ contentsDeductibleCode                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ netContentsPaymentAmount                   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ contentsPropertyValue                      │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ disasterAssistanceCoverageRequired         │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ eventDesignationNumber                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ ficoNumber                                 │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodCharacteristicsIndicator              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodWaterDuration                         │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodproofedIndicator                      │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodEvent                                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ iccCoverage                                │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ netIccPaymentAmount                        │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipRatedCommunityNumber                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipCommunityNumberCurrent                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipCommunityName                          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nonPaymentReasonContents                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nonPaymentReasonBuilding                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ numberOfUnits                              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingReplacementCost                    │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ contentsReplacementCost                    │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ replacementCostBasis                       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ stateOwnedIndicator                        │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ waterDepth                                 │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodZoneCurrent                           │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingDescriptionCode                    │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ rentalPropertyIndicator                    │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ state                                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ reportedCity                               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ reportedZipCode                            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ countyCode                                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusTract                                │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusBlockGroupFips                       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ latitude                                   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ longitude                                  │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ id                                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ├────────────────────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 73 rows                                                                                6 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # OpenFEMA Dataset: FIMA NFIP Redacted Policies - v2
# https://www.fema.gov/openfema-data-page/fima-nfip-redacted-policies-v2

# %%
# %%time

fips_list = [
    "36005",
    "36047",
    "36061",
    "36081",
    "36085"
]

output_path = "data/nyc-policies.parquet"

fetch_nfip_data("Policies", fips_list=fips_list, output_path=output_path)
# Out:
# 2025-05-31 15:29:39,793 - INFO - Starting download for FIPS 36005
# 2025-05-31 15:29:39,794 - INFO - Requesting: skip=0
# 2025-05-31 15:29:47,170 - INFO - Requesting: skip=10000
# 2025-05-31 15:29:53,903 - INFO - Requesting: skip=20000
# 2025-05-31 15:30:01,326 - INFO - Requesting: skip=30000
# 2025-05-31 15:30:06,200 - INFO - Final page for FIPS 36005 retrieved
# 2025-05-31 15:30:06,201 - INFO - Finished download for FIPS 36005: 35579 records
# 2025-05-31 15:30:06,204 - INFO - Starting download for FIPS 36047
# 2025-05-31 15:30:06,205 - INFO - Requesting: skip=0
# 2025-05-31 15:30:12,881 - INFO - Requesting: skip=10000
# 2025-05-31 15:30:20,467 - INFO - Requesting: skip=20000
# 2025-05-31 15:30:28,335 - INFO - Requesting: skip=30000
# 2025-05-31 15:30:36,298 - INFO - Requesting: skip=40000
# 2025-05-31 15:30:43,166 - INFO - Requesting: skip=50000
# 2025-05-31 15:30:49,867 - INFO - Requesting: skip=60000
# 2025-05-31 15:30:56,149 - INFO - Requesting: skip=70000
# 2025-05-31 15:31:02,575 - INFO - Requesting: skip=80000
# 2025-05-31 15:31:09,639 - INFO - Requesting: skip=90000
# 2025-05-31 15:31:16,981 - INFO - Requesting: skip=100000
# 2025-05-31 15:31:24,220 - INFO - Requesting: skip=110000
# 2025-05-31 15:31:31,138 - INFO - Requesting: skip=120000
# 2025-05-31 15:31:38,619 - INFO - Requesting: skip=130000
# 2025-05-31 15:31:45,826 - INFO - Requesting: skip=140000
# 2025-05-31 15:31:53,008 - INFO - Requesting: skip=150000
# 2025-05-31 15:31:55,185 - INFO - Final page for FIPS 36047 retrieved
# 2025-05-31 15:31:55,186 - INFO - Finished download for FIPS 36047: 152625 records
# 2025-05-31 15:31:55,192 - INFO - Starting download for FIPS 36061
# 2025-05-31 15:31:55,193 - INFO - Requesting: skip=0
# 2025-05-31 15:32:01,753 - INFO - Requesting: skip=10000
# 2025-05-31 15:32:07,500 - INFO - Requesting: skip=20000
# 2025-05-31 15:32:13,903 - INFO - Requesting: skip=30000
# 2025-05-31 15:32:18,787 - INFO - Final page for FIPS 36061 retrieved
# 2025-05-31 15:32:18,788 - INFO - Finished download for FIPS 36061: 37838 records
# 2025-05-31 15:32:18,793 - INFO - Starting download for FIPS 36081
# 2025-05-31 15:32:18,794 - INFO - Requesting: skip=0
# 2025-05-31 15:32:26,700 - INFO - Requesting: skip=10000
# 2025-05-31 15:32:34,664 - INFO - Requesting: skip=20000
# 2025-05-31 15:32:40,819 - INFO - Requesting: skip=30000
# 2025-05-31 15:32:46,633 - INFO - Requesting: skip=40000
# 2025-05-31 15:32:52,760 - INFO - Requesting: skip=50000
# 2025-05-31 15:32:58,189 - INFO - Requesting: skip=60000
# 2025-05-31 15:33:03,599 - INFO - Requesting: skip=70000
# 2025-05-31 15:33:09,187 - INFO - Requesting: skip=80000
# 2025-05-31 15:33:15,431 - INFO - Requesting: skip=90000
# 2025-05-31 15:33:21,892 - INFO - Requesting: skip=100000
# 2025-05-31 15:33:27,668 - INFO - Requesting: skip=110000
# 2025-05-31 15:33:34,302 - INFO - Requesting: skip=120000
# 2025-05-31 15:33:40,286 - INFO - Requesting: skip=130000
# 2025-05-31 15:33:46,996 - INFO - Requesting: skip=140000
# 2025-05-31 15:33:54,590 - INFO - Requesting: skip=150000
# 2025-05-31 15:34:02,720 - INFO - Requesting: skip=160000
# 2025-05-31 15:34:09,439 - INFO - Requesting: skip=170000
# 2025-05-31 15:34:16,080 - INFO - Requesting: skip=180000
# 2025-05-31 15:34:22,260 - INFO - Requesting: skip=190000
# 2025-05-31 15:34:28,347 - INFO - Requesting: skip=200000
# 2025-05-31 15:34:35,670 - INFO - Requesting: skip=210000
# 2025-05-31 15:34:41,375 - INFO - Requesting: skip=220000
# 2025-05-31 15:34:44,982 - INFO - Final page for FIPS 36081 retrieved
# 2025-05-31 15:34:44,983 - INFO - Finished download for FIPS 36081: 222675 records
# 2025-05-31 15:34:44,991 - INFO - Starting download for FIPS 36085
# 2025-05-31 15:34:44,992 - INFO - Requesting: skip=0
# 2025-05-31 15:34:51,890 - INFO - Requesting: skip=10000
# 2025-05-31 15:34:59,583 - INFO - Requesting: skip=20000
# 2025-05-31 15:35:06,680 - INFO - Requesting: skip=30000
# 2025-05-31 15:35:13,701 - INFO - Requesting: skip=40000
# 2025-05-31 15:35:21,402 - INFO - Requesting: skip=50000
# 2025-05-31 15:35:27,062 - INFO - Requesting: skip=60000
# 2025-05-31 15:35:34,458 - INFO - Requesting: skip=70000
# 2025-05-31 15:35:39,784 - INFO - Requesting: skip=80000
# 2025-05-31 15:35:44,771 - INFO - Requesting: skip=90000
# 2025-05-31 15:35:51,375 - INFO - Requesting: skip=100000
# 2025-05-31 15:35:54,878 - INFO - Final page for FIPS 36085 retrieved
# 2025-05-31 15:35:54,879 - INFO - Finished download for FIPS 36085: 104975 records
# 2025-05-31 15:36:09,518 - INFO - Saved 553692 records to data/nyc-policies.parquet
# CPU times: user 30.5 s, sys: 3.65 s, total: 34.1 s
# Wall time: 6min 30s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/nyc-policies.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │     553692 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/nyc-policies.parquet')
    LIMIT 5
""").df()
# Out:
#    agricultureStructureIndicator  baseFloodElevation  \
# 0                          False                 NaN
# 1                          False                 NaN
# 2                          False                13.0
# 3                          False                 NaN
# 4                          False                 NaN
#
#    basementEnclosureCrawlspaceType cancellationDateOfFloodPolicy  \
# 0                              NaN                          None
# 1                              1.0                          None
# 2                              0.0                          None
# 3                              2.0                          None
# 4                              1.0                          None
#
#   condominiumCoverageTypeCode  construction  crsClassCode  \
# 0                           N         False           NaN
# 1                           N         False           NaN
# 2                           N         False           NaN
# 3                           N         False           NaN
# 4                           N         False           NaN
#
#   buildingDeductibleCode contentsDeductibleCode  elevatedBuildingIndicator  \
# 0                      0                      0                      False
# 1                      5                      5                      False
# 2                      0                      0                      False
# 3                   None                      0                      False
# 4                   None                      0                      False
#
#    ... femaRegion  propertyState           reportedCity reportedZipCode  \
# 0  ...        2.0             NY  Currently Unavailable           10475
# 1  ...        2.0             NY  Currently Unavailable           10474
# 2  ...        2.0             NY  Currently Unavailable           10473
# 3  ...        2.0             NY  Currently Unavailable           10462
# 4  ...        2.0             NY  Currently Unavailable           10465
#
#    countyCode  censusTract  censusBlockGroupFips  latitude  longitude  \
# 0       36005  36005030200          360050302003      40.9      -73.8
# 1       36005  36005009300          360050093001      40.8      -73.9
# 2       36005  36005000400          360050004004      40.8      -73.8
# 3       36005  36005009200          360050092002      40.8      -73.8
# 4       36005  36005016000          360050160002      40.8      -73.8
#
#                                      id
# 0  5aaca3b8-03f7-4a82-8636-5fc15c2886d1
# 1  ad5de8ef-83f2-47fb-9fe9-d48ec7ac6068
# 2  bbaa372c-423f-4144-b4dc-61c7a4fe1093
# 3  06122838-e205-4f54-a7c2-3d92e03790c6
# 4  c69f6b9c-14d3-44ac-8074-6757130e2414
#
# [5 rows x 81 columns]

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/nyc-policies.parquet'))
""").show(max_rows=100)
# Out:
# ┌────────────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │              column_name               │ column_type │  null   │   key   │ default │  extra  │
# │                varchar                 │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ agricultureStructureIndicator          │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ baseFloodElevation                     │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ basementEnclosureCrawlspaceType        │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ cancellationDateOfFloodPolicy          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ condominiumCoverageTypeCode            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ construction                           │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ crsClassCode                           │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingDeductibleCode                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ contentsDeductibleCode                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ elevatedBuildingIndicator              │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ elevationCertificateIndicator          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ elevationDifference                    │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ federalPolicyFee                       │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ ratedFloodZone                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ hfiaaSurcharge                         │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ houseOfWorshipIndicator                │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ locationOfContents                     │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ lowestAdjacentGrade                    │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ lowestFloorElevation                   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ nonProfitIndicator                     │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ numberOfFloorsInInsuredBuilding        │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ obstructionType                        │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ occupancyType                          │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ originalConstructionDate               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ originalNBDate                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ policyCost                             │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ policyCount                            │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ policyEffectiveDate                    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ policyTerminationDate                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ policyTermIndicator                    │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ postFIRMConstructionIndicator          │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ primaryResidenceIndicator              │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ rateMethod                             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ regularEmergencyProgramIndicator       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ smallBusinessIndicatorBuilding         │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ totalBuildingInsuranceCoverage         │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ totalContentsInsuranceCoverage         │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ totalInsurancePremiumOfThePolicy       │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ cancellationVoidanceReasonCode         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ subsidizedRateType                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ iccPremium                             │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ reserveFundAssessment                  │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityProbationSurcharge            │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ premiumPaymentIndicator                │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingReplacementCost                │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ basicBuildingRate                      │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ additionalBuildingRate                 │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ basicContentsRate                      │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ AdditionalContentsRate                 │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ enclosureTypeCode                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ buildingDescriptionCode                │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ insuranceToValueCode                   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ postFirmVzoneIndicator                 │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodproofedIndicator                  │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ waitingPeriodType                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ rolloverTransferCode                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ endorsementEffectiveDate               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ propertyPurchaseDate                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ rentalPropertyIndicator                │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ tenantIndicator                        │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ stateOwnedIndicator                    │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ disasterAssistanceCoverageRequiredCode │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ mandatoryPurchaseFlag                  │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ grandfatheringTypeCode                 │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipRatedCommunityNumber               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipCommunityNumberCurrent             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipCommunityName                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ programTypeIndicator                   │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ mapPanelNumber                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ mapPanelSuffix                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodZoneCurrent                       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ femaRegion                             │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ propertyState                          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ reportedCity                           │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ reportedZipCode                        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ countyCode                             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusTract                            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusBlockGroupFips                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ latitude                               │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ longitude                              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ id                                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ├────────────────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 81 rows                                                                            6 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # OpenFEMA Dataset: NFIP Multiple Loss Properties - v1
# https://www.fema.gov/openfema-data-page/nfip-multiple-loss-properties-v1

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipMultipleLossProperties.parquet"

# path of saved file
file_path = "data/NfipMultipleLossProperties.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)

# check if the request was successful (status code 200)
if response.status_code == 200:
    
    # write the content of the response to a file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print("File downloaded successfully.")
    
else:
    print("Failed to download file.")
# Out:
# File downloaded successfully.
# CPU times: user 324 ms, sys: 84.4 ms, total: 409 ms
# Wall time: 55.3 s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipMultipleLossProperties.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │     257374 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipMultipleLossProperties.parquet')
    LIMIT 5
""").df()
# Out:
#   fipsCountyCode    state stateAbbreviation          county zipCode  \
# 0          01001  Alabama                AL  AUTAUGA COUNTY   36066
# 1          01001  Alabama                AL  AUTAUGA COUNTY   36067
# 2          01001  Alabama                AL  AUTAUGA COUNTY   36067
# 3          01001  Alabama                AL  AUTAUGA COUNTY   36066
# 4          01001  Alabama                AL  AUTAUGA COUNTY   36067
#
#   reportedCity communityIdNumber        communityName censusBlockGroup  \
# 0   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010204001
# 1   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010207003
# 2   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010202002
# 3   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010204001
# 4   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010207003
#
#    nfipRl  ...  occupancyType  originalConstructionDate  originalNBDate  \
# 0    True  ...             11                1978-09-15      2023-06-07
# 1    True  ...             14                1989-01-01      2023-09-02
# 2    True  ...              4                1935-01-01      2009-02-02
# 3   False  ...              1                1976-07-01      1986-01-25
# 4    True  ...              4                1978-01-01      1997-07-13
#
#   postFIRMConstructionIndicator primaryResidenceIndicator  mitigatedIndicator  \
# 0                          True                     False               False
# 1                          True                      True               False
# 2                         False                     False                True
# 3                         False                      True                True
# 4                         False                     False               False
#
#    insuredIndicator  totalLosses mostRecentDateofLoss  \
# 0              True            2           2009-05-07
# 1              True            3           2024-01-09
# 2             False            3           2009-05-07
# 3             False            5           2000-09-01
# 4             False            4           2000-09-01
#
#                                      id
# 0  83afd8dc-c235-4f88-9870-095ea987764a
# 1  c93a7608-09d4-482e-9ca7-799bf4e8f977
# 2  0e19f3a6-2b31-4d94-b5fe-eec5985be6da
# 3  1b298520-0bc9-484c-820b-3b86ba949caf
# 4  1bba2518-673b-422a-a8d2-d2954d0b6c27
#
# [5 rows x 27 columns]

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/NfipMultipleLossProperties.parquet'))
""").show(max_rows=100)
# Out:
# ┌───────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │          column_name          │ column_type │  null   │   key   │ default │  extra  │
# │            varchar            │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├───────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ fipsCountyCode                │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ state                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ stateAbbreviation             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ county                        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ zipCode                       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ reportedCity                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityIdNumber             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityName                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusBlockGroup              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipRl                        │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nfipSrl                       │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ fmaRl                         │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ fmaSrl                        │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ asOfDate                      │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ floodZone                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ latitude                      │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ longitude                     │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ occupancyType                 │ SMALLINT    │ YES     │ NULL    │ NULL    │ NULL    │
# │ originalConstructionDate      │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ originalNBDate                │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ postFIRMConstructionIndicator │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ primaryResidenceIndicator     │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ mitigatedIndicator            │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ insuredIndicator              │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ totalLosses                   │ SMALLINT    │ YES     │ NULL    │ NULL    │ NULL    │
# │ mostRecentDateofLoss          │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ id                            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ├───────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 27 rows                                                                   6 columns │
# └─────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # OpenFEMA Dataset: NFIP Residential Penetration Rates - v1
# https://www.fema.gov/openfema-data-page/nfip-residential-penetration-rates-v1

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipResidentialPenetrationRates.parquet"

# path of saved file
file_path = "data/NfipResidentialPenetrationRates.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)

# check if the request was successful (status code 200)
if response.status_code == 200:
    
    # write the content of the response to a file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print("File downloaded successfully.")
    
else:
    print("Failed to download file.")
# Out:
# File downloaded successfully.
# CPU times: user 22.5 ms, sys: 6.62 ms, total: 29.2 ms
# Wall time: 931 ms

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipResidentialPenetrationRates.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │       3162 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipResidentialPenetrationRates.parquet')
    LIMIT 5
""").df()
# Out:
#      state   county  resPenetrationRate  resContractsInForce  \
# 0  Alabama  Autauga              0.0114                  237
# 1  Alabama  Baldwin              0.1078                10501
# 2  Alabama  Barbour              0.0031                   32
# 3  Alabama     Bibb              0.0027                   21
# 4  Alabama   Blount              0.0018                   40
#
#    totalResStructures fipsCode   asOfDate  \
# 0               20789     1001 2025-05-15
# 1               97390     1003 2025-05-15
# 2               10455     1005 2025-05-15
# 3                7693     1007 2025-05-15
# 4               22586     1009 2025-05-15
#
#                                      id
# 0  95f9d9a4-298c-445a-b279-0cfa447d1850
# 1  41afe779-2ce5-43ee-bdd2-1b087261b01a
# 2  9d25a05c-bda0-4bf5-8e9e-55f712f53c9f
# 3  a4c74901-8061-4894-ae12-2ce0659888a8
# 4  cb3af383-fb9e-4d7c-8f72-97b98342b871

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/NfipResidentialPenetrationRates.parquet'))
""")
# Out:
# ┌─────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │     column_name     │ column_type │  null   │   key   │ default │  extra  │
# │       varchar       │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ state               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ county              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ resPenetrationRate  │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ resContractsInForce │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ totalResStructures  │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ fipsCode            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ asOfDate            │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ id                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# └─────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %% [markdown]
# # 2023 NFIP Reinsurance Placement Information
# https://www.fema.gov/about/openfema/data-sets/national-flood-insurance-program-nfip-reinsurance-placement-information

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/sites/default/files/documents/fema_nfip-reinsurance-placement-information_2023.zip"

# path of saved file
file_path = "data/fema_nfip-reinsurance-placement-information_2023.zip"

# send an HTTP GET request to the URL
response = requests.get(url)

# check if the request was successful (status code 200)
if response.status_code == 200:
    
    # write the content of the response to a file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print("File downloaded successfully.")
    
else:
    print("Failed to download file.")
# Out:
# File downloaded successfully.
# CPU times: user 36.1 ms, sys: 24.3 ms, total: 60.4 ms
# Wall time: 750 ms

# %% [markdown]
# Preview files inside ZIP.

# %%
# !unzip -l data/fema_nfip-reinsurance-placement-information_2023.zip
# Out:
# Archive:  data/fema_nfip-reinsurance-placement-information_2023.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#    288003  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_KRSpatialKat_ForMarkets_ControlTotals.pdf
#    342686  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_KRSpatialKat_InlandFlood_xNATCPrecip_ForMarkets_ResultsSummary.pdf
#    350586  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_KRSpatialKat_StormSurge_wNATCPrecip_ForMarkets_ResultsSummary.pdf
#    388991  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_RMSv21_StormSurge_ForMarkets_ControlTotals.pdf
#    667614  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_RMSv21_StormSurge_ForMarkets_ResultsSummary.pdf
#    687022  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_VeriskTSv9_InlandFlood_ForMarkets_ResultsSummary.pdf
#    685523  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_VeriskTSv9_StormSurgewPrecip_ForMarkets_ControlTotals.pdf
#    653862  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_VeriskTSv9_StormSurgewPrecip_ForMarkets_ResultsSummary.pdf
# ---------                     -------
#   4064287                     8 files

# %% [markdown]
# # OpenFEMA Dataset: NFIP Community Layer Comprehensive - v1
# https://www.fema.gov/openfema-data-page/nfip-community-layer-comprehensive-v1

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipCommunityLayerComprehensive.parquet"

# path of saved file
file_path = "data/NfipCommunityLayerComprehensive.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)

# check if the request was successful (status code 200)
if response.status_code == 200:
    
    # write the content of the response to a file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print("File downloaded successfully.")
    
else:
    print("Failed to download file.")
# Out:
# File downloaded successfully.
# CPU times: user 4.78 s, sys: 1.85 s, total: 6.63 s
# Wall time: 1min 50s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipCommunityLayerComprehensive.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      51943 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipCommunityLayerComprehensive.parquet')
    LIMIT 5
""").df()
# Out:
#    id communityIdNumber stateCode countyCode censusGeoid       county  \
# 0   1              None        32      32013     3244000     Humboldt
# 1   2            530297      None       None        None         None
# 2   3            050184        05      05123       05123  St. Francis
# 3   4            400351        40      40059     4009850       Harper
# 4   5            450185        45      45087       45087        Union
#
#                                     communityName communityNameShort  \
# 0                                            None               None
# 1  YAKAMA NATION, CONFEDERATED TRIBES AND BAND OF      YAKAMA NATION
# 2                            ST. FRANCIS COUNTY *       ST. FRANCIS*
# 3                                BUFFALO, TOWN OF            BUFFALO
# 4                                   UNION COUNTY*             UNION*
#
#    censusYear  censusPopulationEntire  ...  cisSource     geometrySource  \
# 0        2023                     124  ...       None  Census Funcstat S
# 1        2023                   16902  ...      PIVOT               NFHL
# 2        2023                   23090  ...      PIVOT      Census County
# 3        2023                    1039  ...      PIVOT       Census Place
# 4        2023                   27244  ...      PIVOT      Census County
#
#   alternateGeoid                                    alternateName  \
# 0           None                                        McDermitt
# 1  53077C_530297  Yakama Nation, CONFEDERATED TRIBES AND BANDS,
# 2           None                                      St. Francis
# 3           None                                          Buffalo
# 4           None                                            Union
#
#     alternateLongName layerCreationNotes censusClassCodes  \
# 0       McDermitt CDP               None               U1
# 1                None               None             None
# 2  St. Francis County               None               H1
# 3        Buffalo town               None               C1
# 4        Union County               None               H1
#
#   censusFunctionalStatusCodes     layerTypeCode  \
# 0                        None  Statistical Area
# 1                        None             TRIBE
# 2                           A            County
# 3                           A             Place
# 4                           A            County
#
#                                        layerGeometry
# 0  {"type":"MultiPolygon","coordinates":[[[[-117....
# 1  {"type":"MultiPolygon","coordinates":[[[[-120....
# 2  {"type":"MultiPolygon","coordinates":[[[[-90.4...
# 3  {"type":"MultiPolygon","coordinates":[[[[-99.6...
# 4  {"type":"MultiPolygon","coordinates":[[[[-81.4...
#
# [5 rows x 23 columns]

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/NfipCommunityLayerComprehensive.parquet'))
""")
# Out:
# ┌─────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │         column_name         │ column_type │  null   │   key   │ default │  extra  │
# │           varchar           │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ id                          │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityIdNumber           │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ stateCode                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ countyCode                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusGeoid                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ county                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityName               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityNameShort          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusYear                  │ SMALLINT    │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusPopulationEntire      │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusHousingUnitsEntire    │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ landAreaEntire              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ cisType                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ cisSource                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ geometrySource              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ alternateGeoid              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ alternateName               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ alternateLongName           │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerCreationNotes          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusClassCodes            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusFunctionalStatusCodes │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerTypeCode               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerGeometry               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ├─────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 23 rows                                                                 6 columns │
# └───────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # OpenFEMA Dataset: NFIP Community Layer No Overlaps Split - v1
# https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-split-v1

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipCommunityLayerNoOverlapsSplit.parquet"

# path of saved file
file_path = "data/NfipCommunityLayerNoOverlapsSplit.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)

# check if the request was successful (status code 200)
if response.status_code == 200:
    
    # write the content of the response to a file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print("File downloaded successfully.")
    
else:
    print("Failed to download file.")
# Out:
# File downloaded successfully.
# CPU times: user 5.03 s, sys: 1.64 s, total: 6.67 s
# Wall time: 2min 34s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipCommunityLayerNoOverlapsSplit.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      37918 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipCommunityLayerNoOverlapsSplit.parquet')
    LIMIT 5
""").df()
# Out:
#    id communityIdNumber stateCode countyCode censusGeoid     county  \
# 0   1            190053        19      19061     1903160    Dubuque
# 1   2            480206        48      48135     4853388      Ector
# 2   3            040040        04      04013     0412000   Maricopa
# 3   4            010200        01      01121     0174592  Talladega
# 4   5            400211        40      40113     4065300      Osage
#
#            communityName communityNameShort  censusYear  \
# 0        ASBURY, CITY OF             ASBURY        2024
# 1        ODESSA, CITY OF             ODESSA        2024
# 2      CHANDLER, CITY OF           CHANDLER        2024
# 3     TALLADEGA, CITY OF          TALLADEGA        2024
# 4  SAND SPRINGS, CITY OF       SAND SPRINGS        2024
#
#    censusPopulationEntire  ...  cisSource  geometrySource  alternateGeoid  \
# 0                    5946  ...      PIVOT    Census Place            None
# 1                  110636  ...      PIVOT    Census Place            None
# 2                  276046  ...      PIVOT    Census Place            None
# 3                   15861  ...      PIVOT    Census Place            None
# 4                     386  ...      PIVOT    Census Place            None
#
#    alternateName  alternateLongName layerCreationNotes censusClassCodes  \
# 0         Asbury        Asbury city               None               C1
# 1         Odessa        Odessa city               None               C1
# 2       Chandler      Chandler city               None               C1
# 3      Talladega     Talladega city               None               C1
# 4   Sand Springs  Sand Springs city               None               C1
#
#   censusFunctionalStatusCodes         layerTypeCode  \
# 0                           A                 Place
# 1                           A  Place (multi-county)
# 2                           A                 Place
# 3                           A                 Place
# 4                           A  Place (multi-county)
#
#                                        layerGeometry
# 0  {"type":"MultiPolygon","coordinates":[[[[-90.8...
# 1  {"type":"MultiPolygon","coordinates":[[[[-102....
# 2  {"type":"MultiPolygon","coordinates":[[[[-111....
# 3  {"type":"MultiPolygon","coordinates":[[[[-86.1...
# 4  {"type":"MultiPolygon","coordinates":[[[[-96.2...
#
# [5 rows x 26 columns]

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/NfipCommunityLayerNoOverlapsSplit.parquet'))
""").show(max_rows=100)
# Out:
# ┌─────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │         column_name         │ column_type │  null   │   key   │ default │  extra  │
# │           varchar           │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ id                          │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityIdNumber           │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ stateCode                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ countyCode                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusGeoid                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ county                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityName               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityNameShort          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusYear                  │ SMALLINT    │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusPopulationEntire      │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusHousingUnitsEntire    │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ landAreaEntire              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusPopulationPunched     │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusHousingUnitsPunched   │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ landArea2D                  │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ cisType                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ cisSource                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ geometrySource              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ alternateGeoid              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ alternateName               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ alternateLongName           │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerCreationNotes          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusClassCodes            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusFunctionalStatusCodes │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerTypeCode               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerGeometry               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ├─────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 26 rows                                                                 6 columns │
# └───────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # OpenFEMA Dataset: NFIP Community Layer No Overlaps Whole - v1
# https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-whole-v1

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipCommunityLayerNoOverlapsWhole.parquet"

# path of saved file
file_path = "data/NfipCommunityLayerNoOverlapsWhole.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)

# check if the request was successful (status code 200)
if response.status_code == 200:
    
    # write the content of the response to a file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print("File downloaded successfully.")
    
else:
    print("Failed to download file.")
# Out:
# File downloaded successfully.
# CPU times: user 5.04 s, sys: 1.45 s, total: 6.49 s
# Wall time: 1min 46s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipCommunityLayerNoOverlapsWhole.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      29898 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipCommunityLayerNoOverlapsWhole.parquet')
    LIMIT 5
""").df()
# Out:
#    id communityIdNumber stateCode countyCode censusGeoid      county  \
# 0   1            120213        12      12099     1239081  Palm Beach
# 1   2            120214        12      12099     1239375  Palm Beach
# 2   3            120215        12      12099     1242700  Palm Beach
# 3   4            120216        12      12099     1242900  Palm Beach
# 4   5            120217        12      12099     1249600  Palm Beach
#
#                   communityName communityNameShort  censusYear  \
# 0    LAKE WORTH BEACH,  CITY OF   LAKE WORTH BEACH        2024
# 1              LANTANA, TOWN OF            LANTANA        2024
# 2            MANALAPAN, TOWN OF          MANALAPAN        2024
# 3        MANGONIA PARK, TOWN OF      MANGONIA PARK        2024
# 4  NORTH PALM BEACH, VILLAGE OF   NORTH PALM BEACH        2024
#
#    censusPopulationEntire  ...  censusHousingUnitsPunched  landAreaPunched  \
# 0                   42219  ...                      17476        17.677492
# 1                   11504  ...                       5659         7.708114
# 2                     419  ...                        306        27.319965
# 3                    2142  ...                        750         1.941475
# 4                   13162  ...                       8023        13.719528
#
#    cisType  cisSource  geometrySource     alternateName censusClassCodes  \
# 0     CITY      PIVOT    Census Place  Lake Worth Beach               C1
# 1     TOWN      PIVOT    Census Place           Lantana               C1
# 2     TOWN      PIVOT    Census Place         Manalapan               C1
# 3     TOWN      PIVOT    Census Place     Mangonia Park               C1
# 4  VILLAGE      PIVOT    Census Place  North Palm Beach               C1
#
#   censusFunctionalStatusCodes layerTypeCode  \
# 0                           A         Place
# 1                           A         Place
# 2                           A         Place
# 3                           A         Place
# 4                           A         Place
#
#                                        layerGeometry
# 0  {"type":"MultiPolygon","coordinates":[[[[-80.0...
# 1  {"type":"MultiPolygon","coordinates":[[[[-80.0...
# 2  {"type":"MultiPolygon","coordinates":[[[[-80.0...
# 3  {"type":"MultiPolygon","coordinates":[[[[-80.0...
# 4  {"type":"MultiPolygon","coordinates":[[[[-80.0...
#
# [5 rows x 23 columns]

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/NfipCommunityLayerNoOverlapsWhole.parquet'))
""")
# Out:
# ┌─────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │         column_name         │ column_type │  null   │   key   │ default │  extra  │
# │           varchar           │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ id                          │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityIdNumber           │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ stateCode                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ countyCode                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusGeoid                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ county                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityName               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityNameShort          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusYear                  │ SMALLINT    │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusPopulationEntire      │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusHousingUnitsEntire    │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ landAreaEntire              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusPopulationPunched     │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusHousingUnitsPunched   │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ landAreaPunched             │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ cisType                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ cisSource                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ geometrySource              │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ alternateName               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusClassCodes            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ censusFunctionalStatusCodes │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerTypeCode               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ layerGeometry               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ├─────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 23 rows                                                                 6 columns │
# └───────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # OpenFEMA Dataset: NFIP Community Status Book - v1
# https://www.fema.gov/openfema-data-page/nfip-community-status-book-v1

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipCommunityStatusBook.parquet"

# path of saved file
file_path = "data/NfipCommunityStatusBook.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)

# check if the request was successful (status code 200)
if response.status_code == 200:
    
    # write the content of the response to a file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print("File downloaded successfully.")
    
else:
    print("Failed to download file.")
# Out:
# File downloaded successfully.
# CPU times: user 37.6 ms, sys: 25.8 ms, total: 63.4 ms
# Wall time: 3.36 s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipCommunityStatusBook.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      25053 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipCommunityStatusBook.parquet')
    LIMIT 5
""").df()
# Out:
#   communityIdNumber              communityName             county state  \
# 0            230563  T06 R18 WELS, TOWNSHIP OF    SOMERSET COUNTY    ME
# 1            010232          OHATCHEE, TOWN OF     CALHOUN COUNTY    AL
# 2            010233            CENTRE, CITY OF    CHEROKEE COUNTY    AL
# 3            120275       GULF BREEZE, CITY OF  SANTA ROSA COUNTY    FL
# 4            120308         EDGEWATER, CITY OF     VOLUSIA COUNTY    FL
#
#   initialFloodHazardBoundaryMap initialFloodInsuranceRateMap  \
# 0                           NaT                          NaT
# 1                    1975-01-31                   2007-09-28
# 2                    1975-02-07                   1980-03-14
# 3                    1974-06-28                   1977-09-01
# 4                    1974-08-23                   1980-09-03
#
#   currentlyEffectiveMapDate regularEmergencyProgramDate  tribal  \
# 0                   (NSFHA)                    04/30/84   False
# 1                  03/16/16                    08/18/04   False
# 2                  03/16/16                    03/14/80   False
# 3                  11/19/21                    09/01/77   False
# 4                  09/29/17                    09/03/80   False
#
#    participatingInNFIP originalEntryDate classRatingEffectiveDate classRating  \
# 0                 True               NaT                      NaT        None
# 1                 True               NaT                      NaT        None
# 2                 True               NaT                      NaT        None
# 3                 True        1993-10-01               2025-04-01           6
# 4                 True        1992-10-01               2025-04-01           6
#
#   sfhaDiscount nonSfhaDiscount             lastRefresh
# 0         None            None 2025-05-14 08:55:53.865
# 1         None            None 2025-05-14 08:54:44.047
# 2         None            None 2025-05-14 08:54:44.061
# 3          20%             10% 2025-05-14 08:55:06.066
# 4          20%             10% 2025-05-14 08:55:06.284

# %%
# preview columns
duckdb.sql("""
    DESCRIBE (FROM read_parquet('data/NfipCommunityStatusBook.parquet'))
""")
# Out:
# ┌───────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │          column_name          │ column_type │  null   │   key   │ default │  extra  │
# │            varchar            │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├───────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ communityIdNumber             │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ communityName                 │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ county                        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ state                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ initialFloodHazardBoundaryMap │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ initialFloodInsuranceRateMap  │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ currentlyEffectiveMapDate     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ regularEmergencyProgramDate   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ tribal                        │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ participatingInNFIP           │ BOOLEAN     │ YES     │ NULL    │ NULL    │ NULL    │
# │ originalEntryDate             │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ classRatingEffectiveDate      │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# │ classRating                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ sfhaDiscount                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nonSfhaDiscount               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ lastRefresh                   │ TIMESTAMP   │ YES     │ NULL    │ NULL    │ NULL    │
# ├───────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 16 rows                                                                   6 columns │
# └─────────────────────────────────────────────────────────────────────────────────────┘
