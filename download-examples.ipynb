# %% [markdown]
# # Download NFIP Datasets from OpenFEMA
# Author: Mark Bauer
#
# # Introduction
# This notebook is designed to help the open source community access and work with National Flood Insurance Program (NFIP) datasets using the OpenFEMA API. It provides straightforward code examples for downloading and previewing the data.
#
# I hope this inspires you to incorporate NFIP datasets into your own projects, and that these examples contribute to a better understanding and study of flood insurance and risk in the United States.

# %%
# import packages
import logging
import os
import time
import json
import tempfile
from datetime import datetime
import requests
from urllib.parse import urlencode
import urllib.request
import zipfile

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import duckdb
import fiona
from shapely import wkt

# %%
# reproducibility
# %reload_ext watermark
# %watermark -v -p requests,pandas,duckdb
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# requests: 2.28.1
# pandas  : 1.5.1
# duckdb  : 1.0.0

# %%
# data retrieved, not to be confused with date of data
current_date = datetime.now()
print(f"The data was retrieved on {current_date.strftime('%Y-%m-%d')}.")
# Out:
# The data was retrieved on 2025-07-19.

# %% [markdown]
# # Overview
# This notebook demonstrates how to download and work with the National Flood Insurance Program (NFIP) [datasets](https://www.fema.gov/about/openfema/data-sets#nfip) from [OpenFEMA](https://www.fema.gov/about/reports-and-data/openfema). The workflows are designed to be efficient, easy to adapt, and easy to understand. These examples also include brief data exploration using [DuckDB](https://duckdb.org/).
#
# ## Datasets
# - [FIMA NFIP Redacted Claims - v2](https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2)
# - [FIMA NFIP Redacted Policies - v2](https://www.fema.gov/openfema-data-page/fima-nfip-redacted-policies-v2)
# - [NFIP Multiple Loss Properties - v1](https://www.fema.gov/openfema-data-page/nfip-multiple-loss-properties-v1)
# - [NFIP Residential Penetration Rates - v1](https://www.fema.gov/openfema-data-page/nfip-residential-penetration-rates-v1)
# - [2023 NFIP Reinsurance Placement Information](https://www.fema.gov/about/openfema/data-sets/national-flood-insurance-program-nfip-reinsurance-placement-information)
# - [NFIP Community Layer Comprehensive - v1](https://www.fema.gov/openfema-data-page/nfip-community-layer-comprehensive-v1)
# - [NFIP Community Layer No Overlaps Split - v1](https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-split-v1)
# - [NFIP Community Layer No Overlaps Whole - v1](https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-whole-v1)
# - [NFIP Community Status Book - v1](https://www.fema.gov/openfema-data-page/nfip-community-status-book-v1)
#
# ## Notes
# - Datasets are downloaded in Parquet format whenever possible for performance.
# - DuckDB is used for querying and previewing the data.
# - The NFIP Community Layers dataset is large and has been excluded from this repository (i.e tracked via .gitignore), but other datasets are included both locally and on GitHub.
# - For the NFIP Policies and Claims datasets, the current focus is on a sample of New York City.
#
# ## Disclaimer
# This analysis uses the Federal Emergency Management Agency’s OpenFEMA API, but is not endorsed by FEMA. The Federal Government or FEMA cannot vouch for the data or analyses derived from these data after the data have been retrieved from the Agency's website(s).
#
# Read more about OpenFEMA's [Terms and Conditions](https://www.fema.gov/about/openfema/terms-conditions).

# %% [markdown]
# # Getting Started: Dataset Metadata
# Before we get started, let's review the metadata for each dataset. Luckily, the OpenFEMA API has a great endpoint for this, [OpenFemaDataSets](https://www.fema.gov/openfema-data-page/openfema-data-sets-v1).
#
# From OpenFEMA Data Sets:
# >Metadata for the OpenFEMA API data sets. It contains attributes regarding the published datasets including but not limited to update frequency, description, version, and deprecation status.

# %%
# construct openfema api url, filter for the NFIP dataset
url = (
    "https://www.fema.gov/api/open/v1/OpenFemaDataSets"
    "?$filter=theme eq 'National Flood Insurance Program'"
)

# specify outfile path
outfile = "data/datasets-nfip.csv"

# send GET request to API
response = requests.get(url)

# parse JSON into dataframe
data = response.json()
metadata_df = pd.DataFrame(data['OpenFemaDataSets'])
    
# save file
metadata_df.to_csv(outfile, index=False)

# examine shape of data   
rows, columns = metadata_df.shape 
print(f"rows: {rows},\ncolumns: {columns}")  

# preview data
metadata_df.head()
# Out:
# rows: 8,
# columns: 39
#     identifier                             name  \
# 0  openfema-78       NfipMultipleLossProperties
# 1  openfema-86  NfipResidentialPenetrationRates
# 2  openfema-39          NfipCommunityStatusBook
# 3  openfema-77  NfipCommunityLayerComprehensive
# 4  openfema-74                 FimaNfipPolicies
#
#                                 title  \
# 0       NFIP Multiple Loss Properties
# 1  NFIP Residential Penetration Rates
# 2          NFIP Community Status Book
# 3  NFIP Community Layer Comprehensive
# 4         FIMA NFIP Redacted Policies
#
#                                          description  \
# 0  This dataset provides information on structure...
# 1  NFIP "take-up rates" or residential penetratio...
# 2  The National Flood Insurance Program (NFIP) en...
# 3  This dataset is also known as the 3d layer and...
# 4  Congress passed the National Flood Insurance A...
#
#                                           webService  \
# ...

# %%
# preview columns
metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   identifier              8 non-null      object
#  1   name                    8 non-null      object
#  2   title                   8 non-null      object
#  3   description             8 non-null      object
#  4   webService              8 non-null      object
#  5   dataDictionary          8 non-null      object
#  6   keyword                 8 non-null      object
#  7   modified                8 non-null      object
#  8   publisher               8 non-null      object
#  9   contactPoint            8 non-null      object
#  10  mbox                    8 non-null      object
#  11  accessLevel             8 non-null      object
#  12  landingPage             8 non-null      object
#  13  temporal                4 non-null      object
# ...

# %% [markdown]
# Because of the large amout of columns, let's page through the dataset to preview all of them.

# %%
# preview first 15 columns
metadata_df.iloc[:, :15]
# Out:
#     identifier                               name  \
# 0  openfema-78         NfipMultipleLossProperties
# 1  openfema-86    NfipResidentialPenetrationRates
# 2  openfema-39            NfipCommunityStatusBook
# 3  openfema-77    NfipCommunityLayerComprehensive
# 4  openfema-74                   FimaNfipPolicies
# 5  openfema-73                     FimaNfipClaims
# 6  openfema-76  NfipCommunityLayerNoOverlapsSplit
# 7  openfema-75  NfipCommunityLayerNoOverlapsWhole
#
#                                     title  \
# 0           NFIP Multiple Loss Properties
# 1      NFIP Residential Penetration Rates
# 2              NFIP Community Status Book
# 3      NFIP Community Layer Comprehensive
# 4             FIMA NFIP Redacted Policies
# 5               FIMA NFIP Redacted Claims
# 6  NFIP Community Layer No Overlaps Split
# 7  NFIP Community Layer No Overlaps Whole
#
#                                          description  \
# 0  This dataset provides information on structure...
# ...

# %%
# preview next 15 columns
metadata_df.iloc[:, 15:30]
# Out:
#    version bureauCode programCode accessLevelComment license spatial  \
# 0        1   [024:70]   [024:039]               None    None    None
# 1        1   [024:70]   [024:039]               None    None    None
# 2        1   [024:70]   [024:039]               None    None    None
# 3        1   [024:70]   [024:039]               None    None    None
# 4        2   [024:70]   [024:039]               None    None    None
# 5        2   [024:70]   [024:039]               None    None    None
# 6        1   [024:70]   [024:039]               None    None    None
# 7        1   [024:70]   [024:039]               None    None    None
#
#                               theme dataQuality accrualPeriodicity language  \
# 0  National Flood Insurance Program        true              R/P1Y    en-US
# 1  National Flood Insurance Program        true              R/P3M    en-US
# 2  National Flood Insurance Program        true              R/P1D    en-US
# ...

# %%
# preview columns to the end
metadata_df.iloc[:, 30:]
# Out:
#   depDate depApiMessage depWebMessage depNewURL  \
# 0    None          None          None      None
# 1    None          None          None      None
# 2    None          None          None      None
# 3    None          None          None      None
# 4    None          None          None      None
# 5    None          None          None      None
# 6    None          None          None      None
# 7    None          None          None      None
#
#                                        hash               lastRefresh  \
# 0  c6474d2bed656468b54afcb63f3da841959535a5  2024-11-21T14:40:15.168Z
# 1  402b07b9235ecb551c489e1afcd1c0f09a2d19f8  2025-07-08T16:20:58.984Z
# 2  7b8f6d05763d0c656c524c44438e1d8e8552abe8  2024-11-21T14:40:15.168Z
# 3  51551de69709270cbb3dc05a9da88e92be099c2d  2024-12-05T22:20:23.322Z
# 4  85c6b91e237853b3333b06b4e3ebf5cdef930060  2025-04-01T20:00:37.246Z
# 5  843979427d2c4cc20e139ce661e6b0476975431f  2024-11-21T14:40:15.168Z
# ...

# %%
# print dataset descriptions
for i, row in metadata_df.iterrows():
    print(f"{i + 1}: {row['title']}\n------------")
    print(f"{row['description']}\n")
# Out:
# 1: NFIP Multiple Loss Properties
# ------------
# This dataset provides information on structures that have had multiple National Flood Insurance (NFIP) claims across the history of the program. The data contains NFIP-insured structures that fall within the four categories of Repetitive Loss and Severe Repetitive Loss that FEMA tracks. Definitions of these categories are provided in the field descriptions. There are also fields to show whether a structure is currently NFIP-insured, has been mitigated, and other characteristics. The data includes properties that have since been mitigated or demolished and may no longer considered to be in any of the listed categories.
# An online map of this data can be found on FEMA's ArcGIS Online platform: https://fema.maps.arcgis.com/home/webmap/viewer.html?webmap=872bbaf7dfbb48cb88d244c7123e4d9d
# ...

# %% [markdown]
# # OpenFEMA Dataset Fields

# %% [markdown]
# Another useful OpenFEMA API endpoint is [OpenFemaDataSetFields](https://www.fema.gov/openfema-data-page/openfema-data-set-fields-v1).
#
# From OpenFEMA Data Sets:
# >Metadata for the OpenFEMA API data set fields. It contains descriptions, data types, and other attributes for each field.

# %% [markdown]
# Let's examine and save the fields for NFIP Claims and Policies datasets.

# %% [markdown]
# ## NFIP Claims and Policies Dataset Fields

# %%
# examine dataset and version. We need to pass the dataset version to the dataset fields endpoint.
metadata_df.loc[:, ['name', 'version']]
# Out:
#                                 name  version
# 0         NfipMultipleLossProperties        1
# 1    NfipResidentialPenetrationRates        1
# 2            NfipCommunityStatusBook        1
# 3    NfipCommunityLayerComprehensive        1
# 4                   FimaNfipPolicies        2
# 5                     FimaNfipClaims        2
# 6  NfipCommunityLayerNoOverlapsSplit        1
# 7  NfipCommunityLayerNoOverlapsWhole        1

# %%
# NFIP Claims

# dataset name
name = "FimaNfipClaims"
version = "2"

# construct url
url = (
    "https://www.fema.gov/api/open/v1/OpenFemaDataSetFields"
    f"?$filter=openFemaDataSet%20eq%20%27{name}%27%20and%20datasetVersion%20eq%20{version}"
)

# specify outfile path
outfile = "data/data-dictionary-claims.csv"

# GET request with dataset fields API
response = requests.get(url)
data = response.json()
print("Top-level keys:", list(data.keys()))
    
# transform to dataframe 
fields_df = pd.DataFrame(data['OpenFemaDataSetFields'])   
fields_df.to_csv(outfile, index=False)

# preview data
print(fields_df.shape)
fields_df.head()
# Out:
# Top-level keys: ['metadata', 'OpenFemaDataSetFields']
# (73, 16)
#      datasetId openFemaDataSet  datasetVersion  \
# 0  openfema-73  FimaNfipClaims               2
# 1  openfema-73  FimaNfipClaims               2
# 2  openfema-73  FimaNfipClaims               2
# 3  openfema-73  FimaNfipClaims               2
# 4  openfema-73  FimaNfipClaims               2
#
#                                          name  \
# 0                                    asOfDate
# 1                   amountPaidOnBuildingClaim
# 2                   amountPaidOnContentsClaim
# 3  amountPaidOnIncreasedCostOfComplianceClaim
# 4                    netBuildingPaymentAmount
#
#                                                title  \
# 0                                         As of Date
# 1                      Amount Paid on Building Claim
# 2                      Amount Paid on Contents Claim
# 3  Amount Paid on Increased Cost of Compliance (I...
# 4                        Net Building Payment Amount
#
# ...

# %%
# preview fields
fields_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datasetId        73 non-null     object
#  1   openFemaDataSet  73 non-null     object
#  2   datasetVersion   73 non-null     int64
#  3   name             73 non-null     object
#  4   title            73 non-null     object
#  5   description      73 non-null     object
#  6   type             73 non-null     object
#  7   sortOrder        73 non-null     int64
#  8   isSearchable     73 non-null     bool
#  9   isNestedObject   73 non-null     bool
#  10  isNullable       73 non-null     bool
#  11  primaryKey       73 non-null     bool
#  12  id               73 non-null     object
#  13  lastRefresh      73 non-null     object
#  14  hash             73 non-null     object
#  15  srid             0 non-null      object
# dtypes: bool(4), int64(2), object(10)
# ...

# %%
# NFIP Policies

# dataset name
name = "FimaNfipPolicies"
version = "2"

# construct url
url = (
    "https://www.fema.gov/api/open/v1/OpenFemaDataSetFields"
    f"?$filter=openFemaDataSet%20eq%20%27{name}%27%20and%20datasetVersion%20eq%20{version}"
)

# specify outfile path
outfile = "data/data-dictionary-policies.csv"

# GET request with dataset fields API
response = requests.get(url)
data = response.json()
print("Top-level keys:", list(data.keys()))
    
# transform to dataframe 
fields_df = pd.DataFrame(data['OpenFemaDataSetFields'])   
fields_df.to_csv(outfile, index=False)

# preview data
print(fields_df.shape)
fields_df.head()
# Out:
# Top-level keys: ['metadata', 'OpenFemaDataSetFields']
# (81, 16)
#      datasetId   openFemaDataSet  datasetVersion  \
# 0  openfema-74  FimaNfipPolicies               2
# 1  openfema-74  FimaNfipPolicies               2
# 2  openfema-74  FimaNfipPolicies               2
# 3  openfema-74  FimaNfipPolicies               2
# 4  openfema-74  FimaNfipPolicies               2
#
#                              name                              title  \
# 0         buildingReplacementCost          Building Replacement Cost
# 1              baseFloodElevation               Base Flood Elevation
# 2             lowestAdjacentGrade              Lowest Adjacent Grade
# 3            lowestFloorElevation             Lowest Floor Elevation
# 4  cancellationVoidanceReasonCode  Cancellation/Voidance Reason Code
#
#                                          description          type  sortOrder  \
# 0  Estimated cost in whole dollars to replace the...        bigint         45
# ...

# %% [markdown]
# # Downloading NFIP Datasets
#
# The code below demonstrates how to download NFIP Policies and Claims datasets using the OpenFEMA API. This tutorial focuses specifically on data from **New York City**.
#
# > 💡 You also have the option to download the full datasets in bulk as Parquet files.
#
# ## Understanding County FIPS Codes
#
# To use the NFIP Claims and Policies function, you'll need to provide a **County FIPS code** — a unique identifier for each U.S. county.
#
# - 📄 [FIPS Code Reference (PDF)](https://www2.census.gov/programs-surveys/decennial/2010/partners/pdf/FIPS_StateCounty_Code.pdf)
# - 🗺️ [FIPS Code Map by State](https://www.weather.gov/pimar/FIPSCodes)
# - 🧾 [Census ANSI/FIPS Code Documentation](https://www.census.gov/library/reference/code-lists/ansi.html)

# %%
# constants
BASE_URL = "https://www.fema.gov/api/open/v2/FimaNfip{}"
PAGE_SIZE = 10_000
ALLOWED_DATASETS = {"Claims", "Policies"}

# configure logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# build openFEMA API, includes dataset, FIPS code and pagination
def build_url(dataset, fips, skip):
    return (
        f"{BASE_URL.format(dataset)}"
        "?$format=parquet"
        f"&$filter=countyCode eq '{fips}'"
        f"&$top={PAGE_SIZE}"
        f"&$skip={skip}"
    )

# download dataset and save as Parquet file
def fetch_nfip_data(dataset, fips, outpath=".", sleep_secs=2.0):
    """
    Downloads FEMA NFIP data (Claims or Policies) for a given county FIPS code,
    handling pagination and writing the result as a single Parquet file.

    Parameters:
        dataset (str): 'Claims' or 'Policies'
        fips (str): 5-digit FIPS county code
        outpath (str): Output directory for final Parquet file
        sleep_secs (float): Seconds to sleep between paged requests
    """
    dataset_cap = dataset.capitalize()
    if dataset_cap not in ALLOWED_DATASETS:
        raise ValueError(f"Invalid dataset '{dataset}'. Must be one of {ALLOWED_DATASETS}")

    # ensure output directory exists    
    os.makedirs(outpath, exist_ok=True)
    output_file = os.path.join(outpath, f"{dataset.lower()}-{fips}.parquet")

    # use temporary directory to store paginated Parquet files
    with tempfile.TemporaryDirectory() as tmpdir:
        skip = 0
        total_records = 0

        logging.info(f"Starting download for FIPS {fips}, dataset '{dataset_cap}'")

        # loop through API pages until no more data
        while True:
            url = build_url(dataset_cap, fips, skip)
            logging.info(f"Requesting page: skip={skip}")

            page_path = os.path.join(tmpdir, f"page_{skip}.parquet")

            try:
                # fetch data 
                response = requests.get(url, timeout=60)
                response.raise_for_status()
                # save response content as chunks
                with open(page_path, "wb") as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
            except Exception as e:
                logging.error(f"Request failed at skip={skip}: {e}")
                raise

            try:
                # use DuckDB to count records in the downloaded Parquet
                con = duckdb.connect()
                result = con.execute(f"SELECT COUNT(*) FROM read_parquet('{page_path}')").fetchone()
                page_count = result[0]
                con.close()
            except Exception as e:
                logging.error(f"Parquet read failed at skip={skip}: {e}")
                os.remove(page_path) # clean up corrupted page
                raise

            # stop if no records returned    
            if page_count == 0:
                logging.info(f"No more data returned at skip={skip}. Ending.")
                os.remove(page_path)
                break

            total_records += page_count
            logging.info(f"Page loaded: {page_count} records")

            # if fewer than PAGE_SIZE, assume last page
            if page_count < PAGE_SIZE:
                logging.info("Final page detected.")
                break

            # increment skip to get next page    
            skip += PAGE_SIZE
            time.sleep(sleep_secs)

        # if any data was fetched, combine and write final output    
        if total_records > 0:
            try:
                con = duckdb.connect()
                input_glob = os.path.join(tmpdir, "*.parquet")
                    
                # use DuckDB to merge all paginated files and write a single Parquet file
                con.execute(f"""
                    COPY (SELECT * FROM read_parquet('{input_glob}'))
                    TO '{output_file}' (FORMAT PARQUET)
                """)
                logging.info(f"Wrote {total_records:,} records to {output_file}")
                con.close()
            except Exception as e:
                logging.error(f"Failed to write output Parquet: {e}")
                raise
        else:
            logging.warning("No data fetched. Nothing saved.")

# %% [markdown]
# ## FIMA NFIP Redacted Claims - v2
# Link: https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2
#
# >This dataset provides details on NFIP claims transactions. It is derived from the NFIP system of record, staged in the NFIP reporting platform and redacted to protect policy holder personally identifiable information.

# %%
# %%time

# specify County FIPS codes
fips_list = [
    "36005", # Bronx
    "36047", # Kings (Brooklyn)
    "36061", # New York (Manhattan)
    "36081", # Queens
    "36085" # Richmond (Staten Island)
]

# Claims or Policies
dataset = "Claims"

# specify outpath
outpath = "data/"

# loop over County FIPS codes
for fips in fips_list:
    
    # pass variables to function
    fetch_nfip_data(dataset, fips, outpath)
# Out:
# 2025-07-19 12:23:11,964 - INFO - Starting download for FIPS 36005, dataset 'Claims'
# 2025-07-19 12:23:11,965 - INFO - Requesting page: skip=0
# 2025-07-19 12:23:15,307 - INFO - Page loaded: 1942 records
# 2025-07-19 12:23:15,308 - INFO - Final page detected.
# 2025-07-19 12:23:15,337 - INFO - Wrote 1,942 records to data/claims-36005.parquet
# 2025-07-19 12:23:15,340 - INFO - Starting download for FIPS 36047, dataset 'Claims'
# 2025-07-19 12:23:15,340 - INFO - Requesting page: skip=0
# 2025-07-19 12:23:19,050 - INFO - Page loaded: 6265 records
# 2025-07-19 12:23:19,051 - INFO - Final page detected.
# 2025-07-19 12:23:19,122 - INFO - Wrote 6,265 records to data/claims-36047.parquet
# 2025-07-19 12:23:19,126 - INFO - Starting download for FIPS 36061, dataset 'Claims'
# 2025-07-19 12:23:19,127 - INFO - Requesting page: skip=0
# 2025-07-19 12:23:21,737 - INFO - Page loaded: 1484 records
# 2025-07-19 12:23:21,738 - INFO - Final page detected.
# ...

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/claims-*.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      43981 │
# └────────────┘

# %%
# preview first five rows
sql = """
    SELECT *
    FROM read_parquet('data/claims-*.parquet')
    LIMIT 5
"""

df = duckdb.sql(sql).df()
print(df.shape)
# Out:
# (5, 73)

# %%
# preview first 15 columns
df.iloc[:, :15]
# Out:
#                                      id  agricultureStructureIndicator  \
# 0  166eb26d-1103-4b12-b59d-449c9d944a6f                          False
# 1  8df05ef8-3d60-4ad6-9b2c-7e93171d66c7                          False
# 2  620455d6-0292-4fe3-84c9-e021bbdd27a3                          False
# 3  767fd936-dbb7-477d-bbc6-10bd19045018                          False
# 4  7ba25015-1caf-44f4-b853-4e37d8a03455                          False
#
#     asOfDate  basementEnclosureCrawlspaceType  policyCount  \
# 0 2025-07-01                              2.0            1
# 1 2025-07-01                              1.0            1
# 2 2025-07-01                              NaN            1
# 3 2025-07-01                              NaN            1
# 4 2025-07-01                              2.0            1
#
#    crsClassificationCode dateOfLoss  elevatedBuildingIndicator  \
# 0                    NaN 2010-03-13                      False
# ...

# %%
# slice through next 15 columns
df.iloc[:, 15:30]
# Out:
#    lowestFloorElevation  numberOfFloorsInTheInsuredBuilding  \
# 0                   NaN                                   2
# 1                   NaN                                   1
# 2                   NaN                                   3
# 3                   NaN                                   3
# 4                   NaN                                   1
#
#    nonProfitIndicator  obstructionType  occupancyType  \
# 0               False              NaN              1
# 1               False              NaN             12
# 2               False             10.0              1
# 3               False             10.0              3
# 4               False              NaN             12
#
#   originalConstructionDate originalNBDate  amountPaidOnBuildingClaim  \
# 0               1945-10-20     1999-02-04                   16414.78
# 1               1942-01-01     2009-11-08                    5992.28
# ...

# %%
# slice through next 15 columns
df.iloc[:, 30:45]
# Out:
#    yearOfLoss  primaryResidenceIndicator  buildingDamageAmount  \
# 0        2010                      False               17415.0
# 1        2021                       True                7242.0
# 2        1992                       True               13823.0
# 3        1983                      False                   NaN
# 4        1996                       True                2076.0
#
#   buildingDeductibleCode  netBuildingPaymentAmount  buildingPropertyValue  \
# 0                      2                  16414.78                99238.0
# 1                      2                   5992.28               398115.0
# 2                      1                  13323.22                14600.0
# 3                      0                      0.00                    NaN
# 4                      2                   1576.03               170000.0
#
#   causeOfDamage condominiumCoverageTypeCode  contentsDamageAmount  \
# 0             2                           N                   NaN
# ...

# %%
# slice through next 15 columns
df.iloc[:, 45:60]
# Out:
#    floodCharacteristicsIndicator  floodWaterDuration  floodproofedIndicator  \
# 0                            NaN                 0.0                  False
# 1                            NaN                 NaN                  False
# 2                            NaN                 0.0                  False
# 3                            NaN                 0.0                  False
# 4                            NaN                 0.0                  False
#
#                     floodEvent  iccCoverage  netIccPaymentAmount  \
# 0                   Nor'easter      30000.0                  0.0
# 1                Hurricane Ida      30000.0                  0.0
# 2  December Storm - Nor'easter      20000.0                  0.0
# 3                         None          NaN                  0.0
# 4                     Flooding      30000.0                  0.0
#
#   nfipRatedCommunityNumber nfipCommunityNumberCurrent  nfipCommunityName  \
# ...

# %%
# slice through remaining columns
df.iloc[:, 60:]
# Out:
#    stateOwnedIndicator  waterDepth floodZoneCurrent  buildingDescriptionCode  \
# 0                False          -5             None                      NaN
# 1                False          -7                X                      1.0
# 2                False           0             None                      NaN
# 3                False           0             None                      NaN
# 4                False           0               VE                      1.0
#
#    rentalPropertyIndicator state           reportedCity reportedZipCode  \
# 0                    False    NY  Currently Unavailable           10465
# 1                    False    NY  Currently Unavailable           10473
# 2                    False    NY  Currently Unavailable           10465
# 3                    False    NY  Currently Unavailable           10469
# 4                    False    NY  Currently Unavailable           10465
#
#   countyCode  censusTract censusBlockGroupFips  latitude  longitude
# ...

# %%
# preview columns
duckdb.sql("""
    SELECT
        column_name,
        column_type,
        null_percentage
    FROM (SUMMARIZE (FROM read_parquet('data/claims-*.parquet')))
    ORDER BY null_percentage DESC
""").show(max_rows=80)
# Out:
# ┌────────────────────────────────────────────┬─────────────┬─────────────────┐
# │                column_name                 │ column_type │ null_percentage │
# │                  varchar                   │   varchar   │  decimal(9,2)   │
# ├────────────────────────────────────────────┼─────────────┼─────────────────┤
# │ crsClassificationCode                      │ SMALLINT    │          100.00 │
# │ floodCharacteristicsIndicator              │ SMALLINT    │           99.70 │
# │ eventDesignationNumber                     │ VARCHAR     │           97.31 │
# │ lowestAdjacentGrade                        │ DOUBLE      │           87.20 │
# │ lowestFloorElevation                       │ DOUBLE      │           86.93 │
# │ baseFloodElevation                         │ DOUBLE      │           86.62 │
# │ elevationDifference                        │ DOUBLE      │           86.50 │
# │ nonPaymentReasonBuilding                   │ VARCHAR     │           80.11 │
# ...

# %% [markdown]
# ## FIMA NFIP Redacted Policies - v2
# Link: https://www.fema.gov/openfema-data-page/fima-nfip-redacted-policies-v2
#
# >This dataset provides details on NFIP policy transactions. It is derived from the NFIP system of record, staged in the NFIP reporting platform and redacted to protect policy holder personally identifiable information.

# %%
# %%time

# specify County FIPS codes
fips_list = [
    "36005", # Bronx
    "36047", # Kings (Brooklyn)
    "36061", # New York (Manhattan)
    "36081", # Queens
    "36085" # Richmond (Staten Island)
]

# Policies dataset
dataset = "Policies"

# specify outpath
outpath = "data/"

# loop through County FIPS codes
for fips in fips_list:
    
    # pass variables to function
    fetch_nfip_data(dataset, fips, outpath)
# Out:
# 2025-07-19 12:23:43,945 - INFO - Starting download for FIPS 36005, dataset 'Policies'
# 2025-07-19 12:23:43,946 - INFO - Requesting page: skip=0
# 2025-07-19 12:23:48,650 - INFO - Page loaded: 10000 records
# 2025-07-19 12:23:50,656 - INFO - Requesting page: skip=10000
# 2025-07-19 12:23:55,585 - INFO - Page loaded: 10000 records
# 2025-07-19 12:23:57,590 - INFO - Requesting page: skip=20000
# 2025-07-19 12:24:02,591 - INFO - Page loaded: 10000 records
# 2025-07-19 12:24:04,592 - INFO - Requesting page: skip=30000
# 2025-07-19 12:24:07,540 - INFO - Page loaded: 5838 records
# 2025-07-19 12:24:07,541 - INFO - Final page detected.
# 2025-07-19 12:24:07,788 - INFO - Wrote 35,838 records to data/policies-36005.parquet
# 2025-07-19 12:24:07,792 - INFO - Starting download for FIPS 36047, dataset 'Policies'
# 2025-07-19 12:24:07,792 - INFO - Requesting page: skip=0
# 2025-07-19 12:24:13,052 - INFO - Page loaded: 10000 records
# 2025-07-19 12:24:15,058 - INFO - Requesting page: skip=10000
# ...

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/policies-*.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │     558330 │
# └────────────┘

# %%
# preview first five rows
sql = """
    SELECT *
    FROM read_parquet('data/policies-*.parquet')
    LIMIT 5
"""

df = duckdb.sql(sql).df()
print(df.shape)
# Out:
# (5, 81)

# %%
# slice through columns for readability
df.iloc[:, :15]
# Out:
#    agricultureStructureIndicator  baseFloodElevation  \
# 0                          False                13.0
# 1                          False                 NaN
# 2                          False                 NaN
# 3                          False                 NaN
# 4                          False                 NaN
#
#    basementEnclosureCrawlspaceType cancellationDateOfFloodPolicy  \
# 0                              0.0                           NaT
# 1                              NaN                           NaT
# 2                              2.0                           NaT
# 3                              1.0                           NaT
# 4                              1.0                           NaT
#
#   condominiumCoverageTypeCode  construction  crsClassCode  \
# 0                           N         False           NaN
# 1                           N         False           NaN
# 2                           N         False           NaN
# ...

# %%
df.iloc[:, 15:30]
# Out:
#    houseOfWorshipIndicator  locationOfContents  lowestAdjacentGrade  \
# 0                    False                   4                 16.5
# 1                    False                   3                  NaN
# 2                    False                   2                  NaN
# 3                    False                   2                  NaN
# 4                    False                   2                  NaN
#
#    lowestFloorElevation  nonProfitIndicator  numberOfFloorsInInsuredBuilding  \
# 0                  17.8               False                                2
# 1                   NaN               False                                3
# 2                   NaN               False                                2
# 3                   NaN               False                                2
# 4                   NaN               False                                3
#
#    obstructionType  occupancyType originalConstructionDate originalNBDate  \
# ...

# %%
df.iloc[:, 30:45]
# Out:
#    postFIRMConstructionIndicator  primaryResidenceIndicator rateMethod  \
# 0                           True                       True          1
# 1                           True                       True          1
# 2                          False                       True          7
# 3                           True                      False          1
# 4                          False                       True          7
#
#   regularEmergencyProgramIndicator  smallBusinessIndicatorBuilding  \
# 0                                R                           False
# 1                                R                           False
# 2                                R                           False
# 3                                R                           False
# 4                                R                           False
#
#    totalBuildingInsuranceCoverage  totalContentsInsuranceCoverage  \
# ...

# %%
df.iloc[:, 45:60]
# Out:
#    basicBuildingRate  additionalBuildingRate  basicContentsRate  \
# 0               0.24                    0.08               0.38
# 1               0.78                    0.21               1.20
# 2               0.00                    0.00               0.00
# 3               0.95                    0.30               1.58
# 4               0.00                    0.00               0.00
#
#    AdditionalContentsRate enclosureTypeCode  buildingDescriptionCode  \
# 0                    0.12                 N                      NaN
# 1                    0.59              None                      1.0
# 2                    0.00              None                      NaN
# 3                    0.61              None                      8.0
# 4                    0.00              None                      NaN
#
#    insuranceToValueCode  postFirmVzoneIndicator  floodproofedIndicator  \
# 0                   3.0                   False                  False
# ...

# %%
df.iloc[:, 60:75]
# Out:
#    stateOwnedIndicator  disasterAssistanceCoverageRequiredCode  \
# 0                False                                       0
# 1                False                                       0
# 2                False                                       0
# 3                False                                       0
# 4                False                                       0
#
#    mandatoryPurchaseFlag  grandfatheringTypeCode nfipRatedCommunityNumber  \
# 0                  False                     1.0                   360497
# 1                  False                     1.0                   360497
# 2                  False                     NaN                   360497
# 3                  False                     1.0                   360497
# 4                  False                     NaN                   360497
#
#   nfipCommunityNumberCurrent  nfipCommunityName  programTypeIndicator  \
# ...

# %%
df.iloc[:, 75:]
# Out:
#   countyCode  censusTract censusBlockGroupFips  latitude  longitude  \
# 0      36005  36005000400         360050004004      40.8      -73.8
# 1      36005  36005030200         360050302003      40.9      -73.8
# 2      36005  36005009200         360050092002      40.8      -73.8
# 3      36005  36005009300         360050093001      40.8      -73.9
# 4      36005  36005016000         360050160002      40.8      -73.8
#
#                                      id
# 0  14ac971a-c132-4be4-a7d2-271e070d8409
# 1  1204f3fa-e89c-43a4-97b6-748821f25a6e
# 2  c1a1e1a0-5405-41bf-820e-76027c83697a
# 3  0e0b7eca-7cac-4d86-a500-1ac581f66961
# 4  e58aaba4-9b1b-4a88-8849-3ed3788c2dd7

# %%
# preview columns
duckdb.sql("""
    SELECT
        column_name,
        column_type,
        null_percentage
    FROM (SUMMARIZE (FROM read_parquet('data/policies-*.parquet')))
    ORDER BY null_percentage DESC
""").show(max_rows=100)
# Out:
# ┌────────────────────────────────────────┬─────────────┬─────────────────┐
# │              column_name               │ column_type │ null_percentage │
# │                varchar                 │   varchar   │  decimal(9,2)   │
# ├────────────────────────────────────────┼─────────────┼─────────────────┤
# │ crsClassCode                           │ SMALLINT    │           99.98 │
# │ cancellationDateOfFloodPolicy          │ DATE        │           97.35 │
# │ cancellationVoidanceReasonCode         │ VARCHAR     │           97.35 │
# │ obstructionType                        │ SMALLINT    │           87.76 │
# │ lowestAdjacentGrade                    │ DOUBLE      │           78.09 │
# │ baseFloodElevation                     │ DOUBLE      │           78.06 │
# │ lowestFloorElevation                   │ DOUBLE      │           78.02 │
# │ elevationDifference                    │ INTEGER     │           78.00 │
# ...

# %% [markdown]
# ## NFIP Multiple Loss Properties - v1
# Link: https://www.fema.gov/openfema-data-page/nfip-multiple-loss-properties-v1
#
# >This dataset provides information on structures that have had multiple National Flood Insurance (NFIP) claims across the history of the program. The data contains NFIP-insured structures that fall within the four categories of Repetitive Loss and Severe Repetitive Loss that FEMA tracks. Definitions of these categories are provided in the field descriptions. There are also fields to show whether a structure is currently NFIP-insured, has been mitigated, and other characteristics. The data includes properties that have since been mitigated or demolished and may no longer considered to be in any of the listed categories.

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipMultipleLossProperties.parquet"

# path of saved file
file_path = "data/NfipMultipleLossProperties.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)
    
# write the content of the response to a file
with open(file_path, 'wb') as file:
    file.write(response.content)
    print("File downloaded successfully.")
# Out:
# File downloaded successfully.
# CPU times: user 296 ms, sys: 63.5 ms, total: 360 ms
# Wall time: 57.8 s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipMultipleLossProperties.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │     257374 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipMultipleLossProperties.parquet')
    LIMIT 5
""").df()
# Out:
#   fipsCountyCode    state stateAbbreviation          county zipCode  \
# 0          01001  Alabama                AL  AUTAUGA COUNTY   36066
# 1          01001  Alabama                AL  AUTAUGA COUNTY   36067
# 2          01001  Alabama                AL  AUTAUGA COUNTY   36067
# 3          01001  Alabama                AL  AUTAUGA COUNTY   36066
# 4          01001  Alabama                AL  AUTAUGA COUNTY   36067
#
#   reportedCity communityIdNumber        communityName censusBlockGroup  \
# 0   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010204001
# 1   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010207003
# 2   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010202002
# 3   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010204001
# 4   PRATTVILLE            010002  PRATTVILLE, CITY OF     010010207003
#
#    nfipRl  ...  occupancyType  originalConstructionDate  originalNBDate  \
# ...

# %%
# preview columns
duckdb.sql("""
    SELECT
        column_name,
        column_type,
        null_percentage
    FROM (SUMMARIZE (FROM read_parquet('data/NfipMultipleLossProperties.parquet')))
    ORDER BY null_percentage DESC
""").show(max_rows=100)
# Out:
# ┌───────────────────────────────┬─────────────┬─────────────────┐
# │          column_name          │ column_type │ null_percentage │
# │            varchar            │   varchar   │  decimal(9,2)   │
# ├───────────────────────────────┼─────────────┼─────────────────┤
# │ originalConstructionDate      │ DATE        │            6.01 │
# │ censusBlockGroup              │ VARCHAR     │            4.19 │
# │ latitude                      │ DOUBLE      │            4.19 │
# │ longitude                     │ DOUBLE      │            4.19 │
# │ zipCode                       │ VARCHAR     │            1.36 │
# │ county                        │ VARCHAR     │            1.21 │
# │ reportedCity                  │ VARCHAR     │            0.13 │
# │ totalLosses                   │ SMALLINT    │            0.10 │
# │ postFIRMConstructionIndicator │ BOOLEAN     │            0.09 │
# │ mostRecentDateofLoss          │ DATE        │            0.09 │
# ...

# %% [markdown]
# ## NFIP Residential Penetration Rates - v1
# Link: https://www.fema.gov/openfema-data-page/nfip-residential-penetration-rates-v1
#
# >NFIP "take-up rates" or residential penetration rates are an estimate of the percentage of total residential structures covered by an NFIP policy. The NFIP residential penetration rate within an area, such as a county, is the ratio of insured residential structures to total residential structures in that area. Private flood insurance take-up rates are not available to FEMA and therefore, are not included in these estimates. This data can be used for various planning purposes to evaluate community resilience and residual flood risk, help states better understand areas vulnerable to flooding and provide guidance for flood insurance marketing. FEMA derives the number of total residential structures from the 2019 National Structure Inventory (NSI) 2022.
# >
# >Data in this report pertains to RESIDENTIAL properties only.

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipResidentialPenetrationRates.parquet"

# path of saved file
file_path = "data/NfipResidentialPenetrationRates.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)
    
# write the content of the response to a file
with open(file_path, 'wb') as file:
    file.write(response.content)
    print("File downloaded successfully.")
# Out:
# File downloaded successfully.
# CPU times: user 21.3 ms, sys: 7.57 ms, total: 28.9 ms
# Wall time: 757 ms

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipResidentialPenetrationRates.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │       3162 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipResidentialPenetrationRates.parquet')
    LIMIT 5
""").df()
# Out:
#      state   county  resPenetrationRateSfha  resPenetrationRate  \
# 0  Alabama  Autauga                  0.2460              0.0114
# 1  Alabama  Baldwin                  0.6587              0.1078
# 2  Alabama  Barbour                  0.1218              0.0031
# 3  Alabama     Bibb                  0.0321              0.0027
# 4  Alabama   Blount                  0.0838              0.0018
#
#    resContractsInForce  resContractsInForceSfha  totalResStructuresSfha  \
# 0                  237                      154                     626
# 1                10501                     6878                   10442
# 2                   32                       19                     156
# 3                   21                        8                     249
# 4                   40                       16                     191
#
#    totalResStructures fipsCode   asOfDate  \
# 0               20789    01001 2025-05-15
# 1               97390    01003 2025-05-15
# ...

# %%
# preview columns
duckdb.sql("""
    SELECT
        column_name,
        column_type,
        null_percentage
    FROM (SUMMARIZE (FROM read_parquet('data/NfipResidentialPenetrationRates.parquet')))
    ORDER BY null_percentage DESC
""")
# Out:
# ┌─────────────────────────┬─────────────┬─────────────────┐
# │       column_name       │ column_type │ null_percentage │
# │         varchar         │   varchar   │  decimal(9,2)   │
# ├─────────────────────────┼─────────────┼─────────────────┤
# │ resPenetrationRateSfha  │ DOUBLE      │           11.20 │
# │ resPenetrationRate      │ DOUBLE      │            6.01 │
# │ resContractsInForce     │ INTEGER     │            5.44 │
# │ resContractsInForceSfha │ INTEGER     │            5.44 │
# │ totalResStructuresSfha  │ INTEGER     │            0.57 │
# │ totalResStructures      │ INTEGER     │            0.57 │
# │ fipsCode                │ VARCHAR     │            0.57 │
# │ state                   │ VARCHAR     │            0.00 │
# │ county                  │ VARCHAR     │            0.00 │
# │ asOfDate                │ DATE        │            0.00 │
# │ id                      │ VARCHAR     │            0.00 │
# ├─────────────────────────┴─────────────┴─────────────────┤
# ...

# %% [markdown]
# ## 2023 NFIP Reinsurance Placement Information
# Link: https://www.fema.gov/about/openfema/data-sets/national-flood-insurance-program-nfip-reinsurance-placement-information
#
# >We are sharing some of the reinsurance placement information with the general public, because it is important for the nation to more clearly understand our shared flood risk.  The data and information was derived in part using catastrophic flood risk models developed by AIR-Worldwide and RMS, two well known risk model developers.  That information may also be useful for the insurance industry, academics, and others in understanding and studying flood risk within the United States. FEMA looks to continue to foster strong private-public partnerships as FEMA, the public, academia, and the private sector work together to improve flood resiliency in the United States.
#
# This is a ZIP file, so we'll simply download the file locally.

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/sites/default/files/documents/fema_nfip-reinsurance-placement-information_2023.zip"

# path of saved file
file_path = "data/fema_nfip-reinsurance-placement-information_2023.zip"

# send an HTTP GET request to the URL
response = requests.get(url)

# write the content of the response to a file
with open(file_path, 'wb') as file:
    file.write(response.content)
    print("File downloaded successfully.")
# Out:
# File downloaded successfully.
# CPU times: user 36.9 ms, sys: 15.8 ms, total: 52.7 ms
# Wall time: 531 ms

# %% [markdown]
# Preview files inside ZIP.

# %%
# !unzip -l data/fema_nfip-reinsurance-placement-information_2023.zip
# Out:
# Archive:  data/fema_nfip-reinsurance-placement-information_2023.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#    288003  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_KRSpatialKat_ForMarkets_ControlTotals.pdf
#    342686  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_KRSpatialKat_InlandFlood_xNATCPrecip_ForMarkets_ResultsSummary.pdf
#    350586  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_KRSpatialKat_StormSurge_wNATCPrecip_ForMarkets_ResultsSummary.pdf
#    388991  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_RMSv21_StormSurge_ForMarkets_ControlTotals.pdf
#    667614  09-27-2023 12:55   fema_nfip-reinsurance-placement-information_2023/NFIP_2023_RMSv21_StormSurge_ForMarkets_ResultsSummary.pdf
# ...

# %% [markdown]
# ## NFIP Community Layers (GDB)
#
# >The Community Layer datasets contain geospatial community boundaries associated with Census and NFIP data. The dataset does not contain personal identifiable information (PII). The Community Layer can be used to tie Community ID numbers (CID) to jurisdiction, tribal, and special land use area boundaries.
# >
# >A geodatabase (GDB) link is Included in the Full Data section below. The compressed file contains a collection of files that can store, query, and manage both spatial and nonspatial data using software that can read such a file. It contains all of the community layers, not just the layer for which this dataset page describes.
#
# In this section, we’ll demonstrate how to work with the NFIP Community Layers Geodatabase (GDB) and examine the `NfipCommunityLayerComprehensive` layer.
#
# After exploring geographic data, we’ll also show how to download and save the layers as Parquet files for easier analysis and storage.

# %%
# define URLs and paths
url = "https://www.fema.gov/about/reports-and-data/openfema/cl2024_v1.gdb.zip"
zip_path = "data/cl2024_v1.gdb.zip"
extract_dir = "data"

# ensure data folder exists
os.makedirs(extract_dir, exist_ok=True)

# download if not already downloaded
if not os.path.exists(zip_path):
    print("Downloading...")
    urllib.request.urlretrieve(url, zip_path)
    print("Download complete.")
else:
    print("File already downloaded.")

# unzip and detect full .gdb folder path
unzipped_dir = None
if not os.path.exists(os.path.join(extract_dir, "cl2024_v1.gdb")):
    print("Unzipping...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

        # detect full path to the .gdb folder
        extracted_items = zip_ref.namelist()
        gdb_dirs = sorted({item.split('/')[0] for item in extracted_items if item.endswith('.gdb/')})
        
        if gdb_dirs:
            unzipped_dir = os.path.join(extract_dir, gdb_dirs[0])
            print(f"Unzipped to directory: {unzipped_dir}")
        else:
            print("No .gdb folder found in the ZIP.")
    print("Unzip complete.")
else:
    unzipped_dir = os.path.join(extract_dir, "cl2024_v1.gdb")
    print(f"Already unzipped: {unzipped_dir}")
# Out:
# File already downloaded.
# Unzipping...
# Unzipped to directory: data/cl_2024_v01_OpenFEMA.gdb
# Unzip complete.

# %%
# list all layers in the GDB
print("Available layers:")
layers = fiona.listlayers(unzipped_dir)
for i, layer in enumerate(layers):
    print(f"{i+1}. {layer}")
# Out:
# Available layers:
# 1. NfipCommunityLayerNoOverlapsWhole
# 2. NfipCommunityLayerNoOverlapsSplit
# 3. NfipCommunityLayerComprehensive

# %% [markdown]
# Let's exaine the `NfipCommunityLayerComprehensive` layer.

# %%
# %%time

# read one layer into DuckDB using spatial extension
con = duckdb.connect()
con.execute("INSTALL spatial; LOAD spatial;")

# choose a layer to load, for example the first one
selected_layer = "NfipCommunityLayerComprehensive"

# use ST_Read to load the layer into DuckDB
con.execute(f"""
    CREATE OR REPLACE VIEW fema_community_layer AS
    SELECT * FROM st_read('{os.path.abspath(unzipped_dir)}', layer='{selected_layer}');
""")

# pull dataset for New York City
df = con.execute("""
    SELECT
        *,
        ST_AsText(Shape) AS geometry
    FROM fema_community_layer
    WHERE county_fips IN ('36005', '36047', '36061', '36081','36085')
""").df()

# use wkt.loads for WKT strings
df['geometry'] = df['geometry'].apply(wkt.loads)

# convert to GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")

print(gdf.shape)
gdf.head()
# Out:
# (10, 26)
# CPU times: user 2.49 s, sys: 826 ms, total: 3.32 s
# Wall time: 1.87 s
#       id cis_cid state_fips county_fips census_geoid county_name  \
# 0  31201    None         36       36047        36047       Kings
# 1  31816    None         36       36085        36085    Richmond
# 2  16165  360497         36       36047      3651000       Kings
# 3  16156  360497         36       36085      3651000    Richmond
# 4  17242  360497         36       36081      3651000      Queens
#
#   cis_community_name_full cis_community_name_short  census_year   pop_3d  ...  \
# 0                    None                     None         2023  2736074  ...
# 1                    None                     None         2023   495747  ...
# 2       NEW YORK, CITY OF                 NEW YORK         2023  2736074  ...
# 3       NEW YORK, CITY OF                 NEW YORK         2023   495747  ...
# 4       NEW YORK, CITY OF                 NEW YORK         2023  2405464  ...
#
# ...

# %%
# preview columns
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        10 non-null     int32
#  1   cis_cid                   5 non-null      object
#  2   state_fips                10 non-null     object
#  3   county_fips               10 non-null     object
#  4   census_geoid              10 non-null     object
#  5   county_name               10 non-null     object
#  6   cis_community_name_full   5 non-null      object
#  7   cis_community_name_short  5 non-null      object
#  8   census_year               10 non-null     int32
#  9   pop_3d                    10 non-null     int32
#  10  hu_3d                     10 non-null     int32
#  11  area_sqkm_3d              10 non-null     float32
#  12  cis_type                  5 non-null      object
# ...

# %%
# preview plot
gdf.plot(edgecolor="black")

plt.title('New York City')
plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.tight_layout()

# %% [markdown]
# ## NFIP Community Layer Comprehensive - v1
# Link: https://www.fema.gov/openfema-data-page/nfip-community-layer-comprehensive-v1
#
# >This dataset is also known as the 3d layer and contains a fairly comprehensive set of unaltered source geometry polygons that overlap. It is derived from Census, State of Maine, and National Flood Hazard Layer political boundaries.
# >
# >The Community Layer datasets contain geospatial community boundaries associated with Census and NFIP data. The dataset does not contain personal identifiable information (PII). The Community Layer can be used to tie Community ID numbers (CID) to jurisdiction, tribal, and special land use area boundaries.
#
# The same workflow below for the this layer also applies to the two other datasets:
# - [NFIP Community Layer No Overlaps Split](https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-split-v1)
# - [NFIP Community Layer No Overlaps Whole](https://www.fema.gov/openfema-data-page/nfip-community-layer-no-overlaps-whole-v1)

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipCommunityLayerComprehensive.parquet"

# path of saved file
file_path = "data/NfipCommunityLayerComprehensive.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)
 
# write the content of the response to a file
with open(file_path, 'wb') as file:
    file.write(response.content)
    print("File downloaded successfully.")
# Out:
# File downloaded successfully.
# CPU times: user 4.02 s, sys: 801 ms, total: 4.82 s
# Wall time: 11.5 s

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipCommunityLayerComprehensive.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      51943 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipCommunityLayerComprehensive.parquet')
    LIMIT 5
""").df()
# Out:
#    id communityIdNumber stateCode countyCode censusGeoid       county  \
# 0   1              None        32      32013     3244000     Humboldt
# 1   2            530297      None       None        None         None
# 2   3            050184        05      05123       05123  St. Francis
# 3   4            400351        40      40059     4009850       Harper
# 4   5            450185        45      45087       45087        Union
#
#                                     communityName communityNameShort  \
# 0                                            None               None
# 1  YAKAMA NATION, CONFEDERATED TRIBES AND BAND OF      YAKAMA NATION
# 2                            ST. FRANCIS COUNTY *       ST. FRANCIS*
# 3                                BUFFALO, TOWN OF            BUFFALO
# 4                                   UNION COUNTY*             UNION*
#
#    censusYear  censusPopulationEntire  ...  cisSource     geometrySource  \
# ...

# %%
# preview columns
duckdb.sql("""
    SELECT
        column_name,
        column_type,
        null_percentage
    FROM (SUMMARIZE (FROM read_parquet('data/NfipCommunityLayerComprehensive.parquet')))
    ORDER BY null_percentage DESC
""")
# Out:
# ┌─────────────────────────────┬─────────────┬─────────────────┐
# │         column_name         │ column_type │ null_percentage │
# │           varchar           │   varchar   │  decimal(9,2)   │
# ├─────────────────────────────┼─────────────┼─────────────────┤
# │ layerCreationNotes          │ VARCHAR     │           87.24 │
# │ alternateGeoid              │ VARCHAR     │           83.77 │
# │ communityIdNumber           │ VARCHAR     │           29.63 │
# │ communityName               │ VARCHAR     │           29.63 │
# │ communityNameShort          │ VARCHAR     │           29.63 │
# │ cisType                     │ VARCHAR     │           29.63 │
# │ cisSource                   │ VARCHAR     │           29.63 │
# │ censusFunctionalStatusCodes │ VARCHAR     │           28.70 │
# │ censusPopulationEntire      │ INTEGER     │           12.60 │
# │ censusHousingUnitsEntire    │ INTEGER     │           12.60 │
# │ censusGeoid                 │ VARCHAR     │            3.48 │
# ...

# %% [markdown]
# ## NFIP Community Status Book - v1
# Link: https://www.fema.gov/openfema-data-page/nfip-community-status-book-v1
#
# >The National Flood Insurance Program (NFIP) enables property owners to purchase flood insurance; in return, communities agree to adopt and implement local floodplain management regulations that contribute to protecting lives and reducing the risk of new construction and substantial improvements from future flooding. The NFIP Community Status Book dataset contains the current NFIP status of a community which determines whether citizens have the opportunity to purchase flood insurance as well as qualify for disaster assistance. In addition, this dataset provides the available insurance discount rates for communities that participate in the Community Rating System (CRS).

# %%
# %%time

# URL of the Parquet file to download
url = "https://www.fema.gov/api/open/v1/NfipCommunityStatusBook.parquet"

# path of saved file
file_path = "data/NfipCommunityStatusBook.parquet"

# send an HTTP GET request to the URL
response = requests.get(url)

# write the content of the response to a file
with open(file_path, 'wb') as file:
    file.write(response.content)
    print("File downloaded successfull")
# Out:
# File downloaded successfull
# CPU times: user 33.4 ms, sys: 27.5 ms, total: 60.9 ms
# Wall time: 433 ms

# %%
# count rows
duckdb.sql("""
    SELECT count(*) AS count_rows
    FROM read_parquet('data/NfipCommunityStatusBook.parquet')
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │      25053 │
# └────────────┘

# %%
# preview first five rows
duckdb.sql("""
    SELECT *
    FROM read_parquet('data/NfipCommunityStatusBook.parquet')
    LIMIT 5
""").df()
# Out:
#   communityIdNumber              communityName             county state  \
# 0            230563  T06 R18 WELS, TOWNSHIP OF    SOMERSET COUNTY    ME
# 1            010232          OHATCHEE, TOWN OF     CALHOUN COUNTY    AL
# 2            010233            CENTRE, CITY OF    CHEROKEE COUNTY    AL
# 3            120275       GULF BREEZE, CITY OF  SANTA ROSA COUNTY    FL
# 4            120308         EDGEWATER, CITY OF     VOLUSIA COUNTY    FL
#
#   initialFloodHazardBoundaryMap initialFloodInsuranceRateMap  \
# 0                           NaT                          NaT
# 1                    1975-01-31                   2007-09-28
# 2                    1975-02-07                   1980-03-14
# 3                    1974-06-28                   1977-09-01
# 4                    1974-08-23                   1980-09-03
#
#   currentlyEffectiveMapDate regularEmergencyProgramDate  tribal  \
# 0                   (NSFHA)                    04/30/84   False
# ...

# %%
# preview columns
duckdb.sql("""
    SELECT
        column_name,
        column_type,
        null_percentage
    FROM (SUMMARIZE (FROM read_parquet('data/NfipCommunityStatusBook.parquet')))
    ORDER BY null_percentage DESC
""")
# Out:
# ┌───────────────────────────────┬─────────────┬─────────────────┐
# │          column_name          │ column_type │ null_percentage │
# │            varchar            │   varchar   │  decimal(9,2)   │
# ├───────────────────────────────┼─────────────┼─────────────────┤
# │ sfhaDiscount                  │ VARCHAR     │           93.85 │
# │ originalEntryDate             │ DATE        │           92.96 │
# │ classRatingEffectiveDate      │ DATE        │           92.96 │
# │ classRating                   │ VARCHAR     │           92.94 │
# │ nonSfhaDiscount               │ VARCHAR     │           92.94 │
# │ initialFloodHazardBoundaryMap │ DATE        │           20.08 │
# │ initialFloodInsuranceRateMap  │ DATE        │            4.49 │
# │ currentlyEffectiveMapDate     │ VARCHAR     │            0.72 │
# │ regularEmergencyProgramDate   │ VARCHAR     │            0.01 │
# │ communityIdNumber             │ VARCHAR     │            0.00 │
# ...
